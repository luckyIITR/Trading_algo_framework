# %%
import logging
from kiteconnect import KiteConnect
from dotenv import load_dotenv
import os
import json

logging.basicConfig(level=logging.DEBUG)

# Load .env file
load_dotenv("config/.env")

with open("config/zerodha.json", "r") as file:
    config = json.load(file)

class Login:
    def __init__(self):
        self.api_key = os.getenv("api_key")
        self.api_secret = os.getenv("api_secret")
        self.access_token = config['access_token']
        self.kite = KiteConnect(api_key=self.api_key)
        self.kite.set_access_token(self.access_token)
        
        # try to see if token is still valid
        try:
            profile_data = self.kite.profile()
            logging.info(f"User ID: {profile_data['user_id']}, {profile_data['user_name']} Connected!")
        except Exception as e:
            logging.error(f"{e}, Getting new token...")
            self.get_new_token()
        
    def get_new_token(self):
        url = self.kite.login_url()
        print(url)
        request_token = input("Enter Request token: ")
        new_session_data = self.kite.generate_session(request_token=request_token, api_secret=self.api_secret)
        logging.info(f"User ID: {new_session_data['user_id']}, {new_session_data['user_name']} Connected!")
        self.access_token = new_session_data["access_token"]
        self.kite.set_access_token(self.access_token)
        config_data = {
            'access_token' : self.access_token
        }
        with open('config/zerodha.json', 'w') as jsonfile:
            json.dump(config_data, jsonfile, indent=4)
    
    def get_broker_handler(self):
        return self.kite

# %%
import logging
from kiteconnect import KiteTicker
import os
from dotenv import load_dotenv
import json
import time
logging.basicConfig(level=logging.DEBUG)

# Load .env file
load_dotenv("config/.env")

with open("config/zerodha.json", "r") as file:
    config = json.load(file)
    
api_key = os.getenv("api_key")
access_token = config['access_token']

# Initialise
kws = KiteTicker(api_key, access_token)

def on_ticks(ws, ticks):
    # Callback to receive ticks.
    logging.debug("Ticks: {}".format(ticks))

def on_connect(ws, response):
    # Callback on successful connect.
    # Subscribe to a list of instrument_tokens (RELIANCE and ACC here).
    ws.subscribe([738561])

    # Set RELIANCE to tick in `full` mode.
    ws.set_mode(ws.MODE_LTP, [738561])

def on_close(ws, code, reason):
    # On connection close stop the event loop.
    # Reconnection will not happen after executing `ws.stop()`
    print("Connect is closing......")
    ws.stop()

def on_order_update(ws, data):
    # On connection close stop the event loop.
    # Reconnection will not happen after executing `ws.stop()`
    logging.info(f"orderUpdate : {data}")

# Assign the callbacks.
kws.on_ticks = on_ticks
kws.on_connect = on_connect
kws.on_close = on_close
kws.on_order_update = on_order_update

# Infinite loop on the main thread. Nothing after this will run.
# You have to use the pre-defined callbacks to manage subscriptions.
try:
    kws.connect(threaded=True)
except KeyboardInterrupt:
    logging.info("WebSocket connection interrupted by user.")
    kws.stop()
# Out:
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1231.0}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1231.05}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1231.0}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1230.9}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1230.6}]
# INFO:root:orderUpdate : {'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201576779', 'exchange_order_id': '1100000043979126', 'parent_order_id': None, 'status': 'OPEN', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 13:48:34', 'exchange_update_timestamp': '2024-12-19 13:48:34', 'exchange_timestamp': '2024-12-19 13:48:34', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 0, 'filled_quantity': 0, 'pending_quantity': 1, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032XLbfaXmugwyxz'}
# INFO:root:orderUpdate : {'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201576779', 'exchange_order_id': '1100000043979126', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 13:48:34', 'exchange_update_timestamp': '2024-12-19 13:48:34', 'exchange_timestamp': '2024-12-19 13:48:34', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.3, 'filled_quantity': 1, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032XLbfaXmugwyxz'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201577784', 'exchange_order_id': '1100000044013302', 'parent_order_id': None, 'status': 'OPEN', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 13:48:54', 'exchange_update_timestamp': '2024-12-19 13:48:54', 'exchange_timestamp': '2024-12-19 13:48:54', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 0, 'filled_quantity': 0, 'pending_quantity': 1, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032XOuwdMPZaoaIO'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201577784', 'exchange_order_id': '1100000044013302', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 13:48:54', 'exchange_update_timestamp': '2024-12-19 13:48:54', 'exchange_timestamp': '2024-12-19 13:48:54', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.3, 'filled_quantity': 1, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032XOuwdMPZaoaIO'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201704535', 'exchange_order_id': '1100000048234328', 'parent_order_id': None, 'status': 'OPEN', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 14:27:22', 'exchange_update_timestamp': '2024-12-19 14:27:21', 'exchange_timestamp': '2024-12-19 14:27:21', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 0, 'filled_quantity': 0, 'pending_quantity': 1, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032X9cJoMFl0bkFz'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201704535', 'exchange_order_id': '1100000048234328', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 14:27:22', 'exchange_update_timestamp': '2024-12-19 14:27:21', 'exchange_timestamp': '2024-12-19 14:27:21', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.45, 'filled_quantity': 1, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032X9cJoMFl0bkFz'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201823692', 'exchange_order_id': '1100000052441712', 'parent_order_id': None, 'status': 'OPEN', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 15:01:10', 'exchange_update_timestamp': '2024-12-19 15:01:10', 'exchange_timestamp': '2024-12-19 15:01:10', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'SELL', 'validity': 'DAY', 'product': 'CNC', 'quantity': 1, 'disclosed_quantity': 1, 'price': 0, 'trigger_price': 0, 'average_price': 0, 'filled_quantity': 0, 'pending_quantity': 1, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '3106Xu5m5dwsYkt3s'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201823692', 'exchange_order_id': '1100000052441712', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 15:01:10', 'exchange_update_timestamp': '2024-12-19 15:01:10', 'exchange_timestamp': '2024-12-19 15:01:10', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'SELL', 'validity': 'DAY', 'product': 'CNC', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.35, 'filled_quantity': 1, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '3106Xu5m5dwsYkt3s'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201824025', 'exchange_order_id': '1100000052452485', 'parent_order_id': None, 'status': 'OPEN', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 15:01:14', 'exchange_update_timestamp': '2024-12-19 15:01:14', 'exchange_timestamp': '2024-12-19 15:01:14', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'SELL', 'validity': 'DAY', 'product': 'MIS', 'quantity': 10, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 0, 'filled_quantity': 0, 'pending_quantity': 10, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '3106Xpioxpjhqwubd'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201824025', 'exchange_order_id': '1100000052452485', 'parent_order_id': None, 'status': 'UPDATE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 15:01:14', 'exchange_update_timestamp': '2024-12-19 15:01:14', 'exchange_timestamp': '2024-12-19 15:01:14', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'SELL', 'validity': 'DAY', 'product': 'MIS', 'quantity': 10, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.35, 'filled_quantity': 9, 'pending_quantity': 1, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '3106Xpioxpjhqwubd'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201824025', 'exchange_order_id': '1100000052452485', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 15:01:14', 'exchange_update_timestamp': '2024-12-19 15:01:14', 'exchange_timestamp': '2024-12-19 15:01:14', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'SELL', 'validity': 'DAY', 'product': 'MIS', 'quantity': 10, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.35, 'filled_quantity': 10, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '3106Xpioxpjhqwubd'}

# %%
kws.unsubscribe([738561])
# Out:
# True

# %%
kws.set_mode(kws.MODE_LTP, [738561])
# Out:
# True

# %%
from pprint import pprint

# %%
obj = Login()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /user/profile HTTP/11" 200 None
# INFO:root:User ID: BI3034, Lucky Kushwaha Connected!

# %%
kite_handler = obj.get_broker_handler()

# %%
data = kite_handler.positions()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /portfolio/positions HTTP/11" 200 None

# %%
kite_handler.instruments('NFO')
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments/NFO HTTP/11" 200 516711
# [{'instrument_token': 8961282,
#   'exchange_token': '35005',
#   'tradingsymbol': 'NIFTY24DECFUT',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8961538,
#   'exchange_token': '35006',
#   'tradingsymbol': 'NIFTY25JANFUT',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8963330,
#   'exchange_token': '35013',
#   'tradingsymbol': 'NIFTY25FEBFUT',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8966402,
#   'exchange_token': '35025',
#   'tradingsymbol': 'BANKNIFTY24DECFUT',
#   'name': 'BANKNIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 24),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 15,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8963074,
#   'exchange_token': '35012',
#   'tradingsymbol': 'BANKNIFTY25JANFUT',
#   'name': 'BANKNIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 29),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 15,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8989954,
#   'exchange_token': '35117',
#   'tradingsymbol': 'BANKNIFTY25FEBFUT',
#   'name': 'BANKNIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 30,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8967170,
#   'exchange_token': '35028',
#   'tradingsymbol': 'AARTIIND24DECFUT',
#   'name': 'AARTIIND',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8970754,
#   'exchange_token': '35042',
#   'tradingsymbol': 'AARTIIND25JANFUT',
#   'name': 'AARTIIND',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8963586,
#   'exchange_token': '35014',
#   'tradingsymbol': 'AARTIIND25FEBFUT',
#   'name': 'AARTIIND',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8967426,
#   'exchange_token': '35029',
#   'tradingsymbol': 'ABB24DECFUT',
#   'name': 'ABB',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8971010,
#   'exchange_token': '35043',
#   'tradingsymbol': 'ABB25JANFUT',
#   'name': 'ABB',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8963842,
#   'exchange_token': '35015',
#   'tradingsymbol': 'ABB25FEBFUT',
#   'name': 'ABB',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8967682,
#   'exchange_token': '35030',
#   'tradingsymbol': 'ABBOTINDIA24DECFUT',
#   'name': 'ABBOTINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 20,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8981762,
#   'exchange_token': '35085',
#   'tradingsymbol': 'ABBOTINDIA25JANFUT',
#   'name': 'ABBOTINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 20,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8964098,
#   'exchange_token': '35016',
#   'tradingsymbol': 'ABBOTINDIA25FEBFUT',
#   'name': 'ABBOTINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 20,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8967938,
#   'exchange_token': '35031',
#   'tradingsymbol': 'ABCAPITAL24DECFUT',
#   'name': 'ABCAPITAL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2700,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8982018,
#   'exchange_token': '35086',
#   'tradingsymbol': 'ABCAPITAL25JANFUT',
#   'name': 'ABCAPITAL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2700,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8964354,
#   'exchange_token': '35017',
#   'tradingsymbol': 'ABCAPITAL25FEBFUT',
#   'name': 'ABCAPITAL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2700,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8972034,
#   'exchange_token': '35047',
#   'tradingsymbol': 'ABFRL24DECFUT',
#   'name': 'ABFRL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2600,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8992514,
#   'exchange_token': '35127',
#   'tradingsymbol': 'ABFRL25JANFUT',
#   'name': 'ABFRL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2600,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8964610,
#   'exchange_token': '35018',
#   'tradingsymbol': 'ABFRL25FEBFUT',
#   'name': 'ABFRL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2600,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8972290,
#   'exchange_token': '35048',
#   'tradingsymbol': 'ACC24DECFUT',
#   'name': 'ACC',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8996354,
#   'exchange_token': '35142',
#   'tradingsymbol': 'ACC25JANFUT',
#   'name': 'ACC',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8964866,
#   'exchange_token': '35019',
#   'tradingsymbol': 'ACC25FEBFUT',
#   'name': 'ACC',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8966658,
#   'exchange_token': '35026',
#   'tradingsymbol': 'ADANIENSOL24DECFUT',
#   'name': 'ADANIENSOL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8966914,
#   'exchange_token': '35027',
#   'tradingsymbol': 'ADANIENSOL25JANFUT',
#   'name': 'ADANIENSOL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8968194,
#   'exchange_token': '35032',
#   'tradingsymbol': 'ADANIENSOL25FEBFUT',
#   'name': 'ADANIENSOL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8975106,
#   'exchange_token': '35059',
#   'tradingsymbol': 'ADANIENT24DECFUT',
#   'name': 'ADANIENT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8997634,
#   'exchange_token': '35147',
#   'tradingsymbol': 'ADANIENT25JANFUT',
#   'name': 'ADANIENT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8968450,
#   'exchange_token': '35033',
#   'tradingsymbol': 'ADANIENT25FEBFUT',
#   'name': 'ADANIENT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8971266,
#   'exchange_token': '35044',
#   'tradingsymbol': 'ADANIGREEN24DECFUT',
#   'name': 'ADANIGREEN',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 375,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8973058,
#   'exchange_token': '35051',
#   'tradingsymbol': 'ADANIGREEN25JANFUT',
#   'name': 'ADANIGREEN',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 375,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8978690,
#   'exchange_token': '35073',
#   'tradingsymbol': 'ADANIGREEN25FEBFUT',
#   'name': 'ADANIGREEN',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 375,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8976642,
#   'exchange_token': '35065',
#   'tradingsymbol': 'ADANIPORTS24DECFUT',
#   'name': 'ADANIPORTS',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 400,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9011202,
#   'exchange_token': '35200',
#   'tradingsymbol': 'ADANIPORTS25JANFUT',
#   'name': 'ADANIPORTS',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 400,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8979458,
#   'exchange_token': '35076',
#   'tradingsymbol': 'ADANIPORTS25FEBFUT',
#   'name': 'ADANIPORTS',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 400,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8978946,
#   'exchange_token': '35074',
#   'tradingsymbol': 'ALKEM24DECFUT',
#   'name': 'ALKEM',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9041154,
#   'exchange_token': '35317',
#   'tradingsymbol': 'ALKEM25JANFUT',
#   'name': 'ALKEM',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8980482,
#   'exchange_token': '35080',
#   'tradingsymbol': 'ALKEM25FEBFUT',
#   'name': 'ALKEM',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8979202,
#   'exchange_token': '35075',
#   'tradingsymbol': 'AMBUJACEM24DECFUT',
#   'name': 'AMBUJACEM',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 900,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9046274,
#   'exchange_token': '35337',
#   'tradingsymbol': 'AMBUJACEM25JANFUT',
#   'name': 'AMBUJACEM',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 900,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8982274,
#   'exchange_token': '35087',
#   'tradingsymbol': 'AMBUJACEM25FEBFUT',
#   'name': 'AMBUJACEM',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 900,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8984066,
#   'exchange_token': '35094',
#   'tradingsymbol': 'ANGELONE24DECFUT',
#   'name': 'ANGELONE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 200,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8990466,
#   'exchange_token': '35119',
#   'tradingsymbol': 'ANGELONE25JANFUT',
#   'name': 'ANGELONE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 200,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8990722,
#   'exchange_token': '35120',
#   'tradingsymbol': 'ANGELONE25FEBFUT',
#   'name': 'ANGELONE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 200,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8992770,
#   'exchange_token': '35128',
#   'tradingsymbol': 'APLAPOLLO24DECFUT',
#   'name': 'APLAPOLLO',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 350,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8994562,
#   'exchange_token': '35135',
#   'tradingsymbol': 'APLAPOLLO25JANFUT',
#   'name': 'APLAPOLLO',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 350,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8996610,
#   'exchange_token': '35143',
#   'tradingsymbol': 'APLAPOLLO25FEBFUT',
#   'name': 'APLAPOLLO',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 350,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8986114,
#   'exchange_token': '35102',
#   'tradingsymbol': 'APOLLOHOSP24DECFUT',
#   'name': 'APOLLOHOSP',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9046786,
#   'exchange_token': '35339',
#   'tradingsymbol': 'APOLLOHOSP25JANFUT',
#   'name': 'APOLLOHOSP',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8996866,
#   'exchange_token': '35144',
#   'tradingsymbol': 'APOLLOHOSP25FEBFUT',
#   'name': 'APOLLOHOSP',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8986882,
#   'exchange_token': '35105',
#   'tradingsymbol': 'APOLLOTYRE24DECFUT',
#   'name': 'APOLLOTYRE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1700,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9047042,
#   'exchange_token': '35340',
#   'tradingsymbol': 'APOLLOTYRE25JANFUT',
#   'name': 'APOLLOTYRE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1700,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8997890,
#   'exchange_token': '35148',
#   'tradingsymbol': 'APOLLOTYRE25FEBFUT',
#   'name': 'APOLLOTYRE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1700,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9022210,
#   'exchange_token': '35243',
#   'tradingsymbol': 'ASHOKLEY24DECFUT',
#   'name': 'ASHOKLEY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9064194,
#   'exchange_token': '35407',
#   'tradingsymbol': 'ASHOKLEY25JANFUT',
#   'name': 'ASHOKLEY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8998914,
#   'exchange_token': '35152',
#   'tradingsymbol': 'ASHOKLEY25FEBFUT',
#   'name': 'ASHOKLEY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9022466,
#   'exchange_token': '35244',
#   'tradingsymbol': 'ASIANPAINT24DECFUT',
#   'name': 'ASIANPAINT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 200,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9065986,
#   'exchange_token': '35414',
#   'tradingsymbol': 'ASIANPAINT25JANFUT',
#   'name': 'ASIANPAINT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 200,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 8999426,
#   'exchange_token': '35154',
#   'tradingsymbol': 'ASIANPAINT25FEBFUT',
#   'name': 'ASIANPAINT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 200,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9029122,
#   'exchange_token': '35270',
#   'tradingsymbol': 'ASTRAL24DECFUT',
#   'name': 'ASTRAL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 367,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9130242,
#   'exchange_token': '35665',
#   'tradingsymbol': 'ASTRAL25JANFUT',
#   'name': 'ASTRAL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 367,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9001986,
#   'exchange_token': '35164',
#   'tradingsymbol': 'ASTRAL25FEBFUT',
#   'name': 'ASTRAL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 367,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9002754,
#   'exchange_token': '35167',
#   'tradingsymbol': 'ATGL24DECFUT',
#   'name': 'ATGL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 775,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9004802,
#   'exchange_token': '35175',
#   'tradingsymbol': 'ATGL25JANFUT',
#   'name': 'ATGL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 775,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9005058,
#   'exchange_token': '35176',
#   'tradingsymbol': 'ATGL25FEBFUT',
#   'name': 'ATGL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 775,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9032706,
#   'exchange_token': '35284',
#   'tradingsymbol': 'ATUL24DECFUT',
#   'name': 'ATUL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9132290,
#   'exchange_token': '35673',
#   'tradingsymbol': 'ATUL25JANFUT',
#   'name': 'ATUL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9032194,
#   'exchange_token': '35282',
#   'tradingsymbol': 'ATUL25FEBFUT',
#   'name': 'ATUL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9032962,
#   'exchange_token': '35285',
#   'tradingsymbol': 'AUBANK24DECFUT',
#   'name': 'AUBANK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9132546,
#   'exchange_token': '35674',
#   'tradingsymbol': 'AUBANK25JANFUT',
#   'name': 'AUBANK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9035522,
#   'exchange_token': '35295',
#   'tradingsymbol': 'AUBANK25FEBFUT',
#   'name': 'AUBANK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9033218,
#   'exchange_token': '35286',
#   'tradingsymbol': 'AUROPHARMA24DECFUT',
#   'name': 'AUROPHARMA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 550,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9133058,
#   'exchange_token': '35676',
#   'tradingsymbol': 'AUROPHARMA25JANFUT',
#   'name': 'AUROPHARMA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 550,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9035778,
#   'exchange_token': '35296',
#   'tradingsymbol': 'AUROPHARMA25FEBFUT',
#   'name': 'AUROPHARMA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 550,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9033474,
#   'exchange_token': '35287',
#   'tradingsymbol': 'AXISBANK24DECFUT',
#   'name': 'AXISBANK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9133314,
#   'exchange_token': '35677',
#   'tradingsymbol': 'AXISBANK25JANFUT',
#   'name': 'AXISBANK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9039362,
#   'exchange_token': '35310',
#   'tradingsymbol': 'AXISBANK25FEBFUT',
#   'name': 'AXISBANK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9033986,
#   'exchange_token': '35289',
#   'tradingsymbol': 'BAJAJ-AUTO24DECFUT',
#   'name': 'BAJAJ-AUTO',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9186562,
#   'exchange_token': '35885',
#   'tradingsymbol': 'BAJAJ-AUTO25JANFUT',
#   'name': 'BAJAJ-AUTO',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9039618,
#   'exchange_token': '35311',
#   'tradingsymbol': 'BAJAJ-AUTO25FEBFUT',
#   'name': 'BAJAJ-AUTO',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9034242,
#   'exchange_token': '35290',
#   'tradingsymbol': 'BAJAJFINSV24DECFUT',
#   'name': 'BAJAJFINSV',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9188866,
#   'exchange_token': '35894',
#   'tradingsymbol': 'BAJAJFINSV25JANFUT',
#   'name': 'BAJAJFINSV',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9039874,
#   'exchange_token': '35312',
#   'tradingsymbol': 'BAJAJFINSV25FEBFUT',
#   'name': 'BAJAJFINSV',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9034498,
#   'exchange_token': '35291',
#   'tradingsymbol': 'BAJFINANCE24DECFUT',
#   'name': 'BAJFINANCE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9289474,
#   'exchange_token': '36287',
#   'tradingsymbol': 'BAJFINANCE25JANFUT',
#   'name': 'BAJFINANCE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9044226,
#   'exchange_token': '35329',
#   'tradingsymbol': 'BAJFINANCE25FEBFUT',
#   'name': 'BAJFINANCE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9036802,
#   'exchange_token': '35300',
#   'tradingsymbol': 'BALKRISIND24DECFUT',
#   'name': 'BALKRISIND',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9406210,
#   'exchange_token': '36743',
#   'tradingsymbol': 'BALKRISIND25JANFUT',
#   'name': 'BALKRISIND',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9045506,
#   'exchange_token': '35334',
#   'tradingsymbol': 'BALKRISIND25FEBFUT',
#   'name': 'BALKRISIND',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 300,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9037058,
#   'exchange_token': '35301',
#   'tradingsymbol': 'BANDHANBNK24DECFUT',
#   'name': 'BANDHANBNK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2800,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9406466,
#   'exchange_token': '36744',
#   'tradingsymbol': 'BANDHANBNK25JANFUT',
#   'name': 'BANDHANBNK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2800,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9045762,
#   'exchange_token': '35335',
#   'tradingsymbol': 'BANDHANBNK25FEBFUT',
#   'name': 'BANDHANBNK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2800,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9037826,
#   'exchange_token': '35304',
#   'tradingsymbol': 'BANKBARODA24DECFUT',
#   'name': 'BANKBARODA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2925,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9406722,
#   'exchange_token': '36745',
#   'tradingsymbol': 'BANKBARODA25JANFUT',
#   'name': 'BANKBARODA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2925,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9060610,
#   'exchange_token': '35393',
#   'tradingsymbol': 'BANKBARODA25FEBFUT',
#   'name': 'BANKBARODA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2925,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9060866,
#   'exchange_token': '35394',
#   'tradingsymbol': 'BANKINDIA24DECFUT',
#   'name': 'BANKINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 4825,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9067522,
#   'exchange_token': '35420',
#   'tradingsymbol': 'BANKINDIA25JANFUT',
#   'name': 'BANKINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 4825,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9067778,
#   'exchange_token': '35421',
#   'tradingsymbol': 'BANKINDIA25FEBFUT',
#   'name': 'BANKINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 4825,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9038082,
#   'exchange_token': '35305',
#   'tradingsymbol': 'BATAINDIA24DECFUT',
#   'name': 'BATAINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 375,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9406978,
#   'exchange_token': '36746',
#   'tradingsymbol': 'BATAINDIA25JANFUT',
#   'name': 'BATAINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 375,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9068034,
#   'exchange_token': '35422',
#   'tradingsymbol': 'BATAINDIA25FEBFUT',
#   'name': 'BATAINDIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 375,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9040642,
#   'exchange_token': '35315',
#   'tradingsymbol': 'BEL24DECFUT',
#   'name': 'BEL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2850,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9538818,
#   'exchange_token': '37261',
#   'tradingsymbol': 'BEL25JANFUT',
#   'name': 'BEL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2850,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9068290,
#   'exchange_token': '35423',
#   'tradingsymbol': 'BEL25FEBFUT',
#   'name': 'BEL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2850,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9041410,
#   'exchange_token': '35318',
#   'tradingsymbol': 'BERGEPAINT24DECFUT',
#   'name': 'BERGEPAINT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1320,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9539074,
#   'exchange_token': '37262',
#   'tradingsymbol': 'BERGEPAINT25JANFUT',
#   'name': 'BERGEPAINT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1320,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9071106,
#   'exchange_token': '35434',
#   'tradingsymbol': 'BERGEPAINT25FEBFUT',
#   'name': 'BERGEPAINT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1320,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9041666,
#   'exchange_token': '35319',
#   'tradingsymbol': 'BHARATFORG24DECFUT',
#   'name': 'BHARATFORG',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9539330,
#   'exchange_token': '37263',
#   'tradingsymbol': 'BHARATFORG25JANFUT',
#   'name': 'BHARATFORG',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9075202,
#   'exchange_token': '35450',
#   'tradingsymbol': 'BHARATFORG25FEBFUT',
#   'name': 'BHARATFORG',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9046018,
#   'exchange_token': '35336',
#   'tradingsymbol': 'BHARTIARTL24DECFUT',
#   'name': 'BHARTIARTL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 475,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9539586,
#   'exchange_token': '37264',
#   'tradingsymbol': 'BHARTIARTL25JANFUT',
#   'name': 'BHARTIARTL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 475,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9075458,
#   'exchange_token': '35451',
#   'tradingsymbol': 'BHARTIARTL25FEBFUT',
#   'name': 'BHARTIARTL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 475,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9108226,
#   'exchange_token': '35579',
#   'tradingsymbol': 'BHEL24DECFUT',
#   'name': 'BHEL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9859074,
#   'exchange_token': '38512',
#   'tradingsymbol': 'BHEL25JANFUT',
#   'name': 'BHEL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9075970,
#   'exchange_token': '35453',
#   'tradingsymbol': 'BHEL25FEBFUT',
#   'name': 'BHEL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2625,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9108738,
#   'exchange_token': '35581',
#   'tradingsymbol': 'BIOCON24DECFUT',
#   'name': 'BIOCON',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10104322,
#   'exchange_token': '39470',
#   'tradingsymbol': 'BIOCON25JANFUT',
#   'name': 'BIOCON',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9076226,
#   'exchange_token': '35454',
#   'tradingsymbol': 'BIOCON25FEBFUT',
#   'name': 'BIOCON',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 2500,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9112066,
#   'exchange_token': '35594',
#   'tradingsymbol': 'BOSCHLTD24DECFUT',
#   'name': 'BOSCHLTD',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10331394,
#   'exchange_token': '40357',
#   'tradingsymbol': 'BOSCHLTD25JANFUT',
#   'name': 'BOSCHLTD',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9076482,
#   'exchange_token': '35455',
#   'tradingsymbol': 'BOSCHLTD25FEBFUT',
#   'name': 'BOSCHLTD',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9124610,
#   'exchange_token': '35643',
#   'tradingsymbol': 'BPCL24DECFUT',
#   'name': 'BPCL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1800,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10331650,
#   'exchange_token': '40358',
#   'tradingsymbol': 'BPCL25JANFUT',
#   'name': 'BPCL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1800,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9076738,
#   'exchange_token': '35456',
#   'tradingsymbol': 'BPCL25FEBFUT',
#   'name': 'BPCL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1800,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9124866,
#   'exchange_token': '35644',
#   'tradingsymbol': 'BRITANNIA24DECFUT',
#   'name': 'BRITANNIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10332162,
#   'exchange_token': '40360',
#   'tradingsymbol': 'BRITANNIA25JANFUT',
#   'name': 'BRITANNIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9076994,
#   'exchange_token': '35457',
#   'tradingsymbol': 'BRITANNIA25FEBFUT',
#   'name': 'BRITANNIA',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 100,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9096706,
#   'exchange_token': '35534',
#   'tradingsymbol': 'BSE24DECFUT',
#   'name': 'BSE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9100034,
#   'exchange_token': '35547',
#   'tradingsymbol': 'BSE25JANFUT',
#   'name': 'BSE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9105666,
#   'exchange_token': '35569',
#   'tradingsymbol': 'BSE25FEBFUT',
#   'name': 'BSE',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9129218,
#   'exchange_token': '35661',
#   'tradingsymbol': 'BSOFT24DECFUT',
#   'name': 'BSOFT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10332418,
#   'exchange_token': '40361',
#   'tradingsymbol': 'BSOFT25JANFUT',
#   'name': 'BSOFT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9141250,
#   'exchange_token': '35708',
#   'tradingsymbol': 'BSOFT25FEBFUT',
#   'name': 'BSOFT',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 1000,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9143042,
#   'exchange_token': '35715',
#   'tradingsymbol': 'CAMS24DECFUT',
#   'name': 'CAMS',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9146370,
#   'exchange_token': '35728',
#   'tradingsymbol': 'CAMS25JANFUT',
#   'name': 'CAMS',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9148418,
#   'exchange_token': '35736',
#   'tradingsymbol': 'CAMS25FEBFUT',
#   'name': 'CAMS',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 125,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9398274,
#   'exchange_token': '36712',
#   'tradingsymbol': 'CANBK24DECFUT',
#   'name': 'CANBK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 6750,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10332674,
#   'exchange_token': '40362',
#   'tradingsymbol': 'CANBK25JANFUT',
#   'name': 'CANBK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 6750,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9170690,
#   'exchange_token': '35823',
#   'tradingsymbol': 'CANBK25FEBFUT',
#   'name': 'CANBK',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 6750,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9398786,
#   'exchange_token': '36714',
#   'tradingsymbol': 'CANFINHOME24DECFUT',
#   'name': 'CANFINHOME',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 975,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10332930,
#   'exchange_token': '40363',
#   'tradingsymbol': 'CANFINHOME25JANFUT',
#   'name': 'CANFINHOME',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 975,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9170946,
#   'exchange_token': '35824',
#   'tradingsymbol': 'CANFINHOME25FEBFUT',
#   'name': 'CANFINHOME',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 975,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9174274,
#   'exchange_token': '35837',
#   'tradingsymbol': 'CDSL24DECFUT',
#   'name': 'CDSL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 350,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9174530,
#   'exchange_token': '35838',
#   'tradingsymbol': 'CDSL25JANFUT',
#   'name': 'CDSL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 350,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9174786,
#   'exchange_token': '35839',
#   'tradingsymbol': 'CDSL25FEBFUT',
#   'name': 'CDSL',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 350,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9238786,
#   'exchange_token': '36089',
#   'tradingsymbol': 'CESC24DECFUT',
#   'name': 'CESC',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2925,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9257986,
#   'exchange_token': '36164',
#   'tradingsymbol': 'CESC25JANFUT',
#   'name': 'CESC',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2925,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9258242,
#   'exchange_token': '36165',
#   'tradingsymbol': 'CESC25FEBFUT',
#   'name': 'CESC',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.01,
#   'lot_size': 2925,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9258498,
#   'exchange_token': '36166',
#   'tradingsymbol': 'CGPOWER24DECFUT',
#   'name': 'CGPOWER',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 725,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9262338,
#   'exchange_token': '36181',
#   'tradingsymbol': 'CGPOWER25JANFUT',
#   'name': 'CGPOWER',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 30),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 725,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9531650,
#   'exchange_token': '37233',
#   'tradingsymbol': 'CGPOWER25FEBFUT',
#   'name': 'CGPOWER',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 2, 27),
#   'strike': 0.0,
#   'tick_size': 0.05,
#   'lot_size': 725,
#   'instrument_type': 'FUT',
#   'segment': 'NFO-FUT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9399554,
#   'exchange_token': '36717',
# ...
#  {'instrument_token': 13170690,
#   'exchange_token': '51448',
#   'tradingsymbol': 'NIFTY24DEC21000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 21000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9807874,
#   'exchange_token': '38312',
#   'tradingsymbol': 'NIFTY24DEC20000CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 20000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 9808642,
#   'exchange_token': '38315',
#   'tradingsymbol': 'NIFTY24DEC20000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 20000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10233858,
#   'exchange_token': '39976',
#   'tradingsymbol': 'NIFTY24DEC19000CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 19000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10234370,
#   'exchange_token': '39978',
#   'tradingsymbol': 'NIFTY24DEC19000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 19000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10501122,
#   'exchange_token': '41020',
#   'tradingsymbol': 'NIFTY24DEC18500CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 18500.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 14109954,
#   'exchange_token': '55117',
#   'tradingsymbol': 'NIFTY24DEC18000CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 18000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 14110210,
#   'exchange_token': '55118',
#   'tradingsymbol': 'NIFTY24DEC18000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 18000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 11739650,
#   'exchange_token': '45858',
#   'tradingsymbol': 'NIFTY24DEC17000CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 17000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 11739906,
#   'exchange_token': '45859',
#   'tradingsymbol': 'NIFTY24DEC17000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 17000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10155266,
#   'exchange_token': '39669',
#   'tradingsymbol': 'NIFTY24DEC16000CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 16000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10156034,
#   'exchange_token': '39672',
#   'tradingsymbol': 'NIFTY24DEC16000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 16000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10262018,
#   'exchange_token': '40086',
#   'tradingsymbol': 'NIFTY24DEC15000CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 15000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 10262274,
#   'exchange_token': '40087',
#   'tradingsymbol': 'NIFTY24DEC15000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 15000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 11106050,
#   'exchange_token': '43383',
#   'tradingsymbol': 'NIFTY24DEC14000CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 14000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 11106306,
#   'exchange_token': '43384',
#   'tradingsymbol': 'NIFTY24DEC14000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2024, 12, 26),
#   'strike': 14000.0,
#   'tick_size': 0.05,
#   'lot_size': 25,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13441026,
#   'exchange_token': '52504',
#   'tradingsymbol': 'NIFTY2510223600CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23600.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13441538,
#   'exchange_token': '52506',
#   'tradingsymbol': 'NIFTY2510223600PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23600.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13439746,
#   'exchange_token': '52499',
#   'tradingsymbol': 'NIFTY2510223550CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23550.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13440258,
#   'exchange_token': '52501',
#   'tradingsymbol': 'NIFTY2510223550PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23550.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13442306,
#   'exchange_token': '52509',
#   'tradingsymbol': 'NIFTY2510223650CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23650.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13442562,
#   'exchange_token': '52510',
#   'tradingsymbol': 'NIFTY2510223650PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23650.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13439234,
#   'exchange_token': '52497',
#   'tradingsymbol': 'NIFTY2510223500CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23500.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13439490,
#   'exchange_token': '52498',
#   'tradingsymbol': 'NIFTY2510223500PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23500.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13442818,
#   'exchange_token': '52511',
#   'tradingsymbol': 'NIFTY2510223700CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23700.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13444866,
#   'exchange_token': '52519',
#   'tradingsymbol': 'NIFTY2510223700PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23700.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13435138,
#   'exchange_token': '52481',
#   'tradingsymbol': 'NIFTY2510223450CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23450.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13438722,
#   'exchange_token': '52495',
#   'tradingsymbol': 'NIFTY2510223450PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23450.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13445122,
#   'exchange_token': '52520',
#   'tradingsymbol': 'NIFTY2510223750CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23750.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13445634,
#   'exchange_token': '52522',
#   'tradingsymbol': 'NIFTY2510223750PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23750.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13433090,
#   'exchange_token': '52473',
#   'tradingsymbol': 'NIFTY2510223400CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23400.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13434370,
#   'exchange_token': '52478',
#   'tradingsymbol': 'NIFTY2510223400PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23400.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13445890,
#   'exchange_token': '52523',
#   'tradingsymbol': 'NIFTY2510223800CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23800.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13446146,
#   'exchange_token': '52524',
#   'tradingsymbol': 'NIFTY2510223800PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23800.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13432578,
#   'exchange_token': '52471',
#   'tradingsymbol': 'NIFTY2510223350CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23350.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13432834,
#   'exchange_token': '52472',
#   'tradingsymbol': 'NIFTY2510223350PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23350.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13446402,
#   'exchange_token': '52525',
#   'tradingsymbol': 'NIFTY2510223850CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23850.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13446658,
#   'exchange_token': '52526',
#   'tradingsymbol': 'NIFTY2510223850PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23850.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13430786,
#   'exchange_token': '52464',
#   'tradingsymbol': 'NIFTY2510223300CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23300.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13431042,
#   'exchange_token': '52465',
#   'tradingsymbol': 'NIFTY2510223300PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23300.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13446914,
#   'exchange_token': '52527',
#   'tradingsymbol': 'NIFTY2510223900CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23900.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13447426,
#   'exchange_token': '52529',
#   'tradingsymbol': 'NIFTY2510223900PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23900.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13430274,
#   'exchange_token': '52462',
#   'tradingsymbol': 'NIFTY2510223250CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23250.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13430530,
#   'exchange_token': '52463',
#   'tradingsymbol': 'NIFTY2510223250PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23250.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13447682,
#   'exchange_token': '52530',
#   'tradingsymbol': 'NIFTY2510223950CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23950.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13449474,
#   'exchange_token': '52537',
#   'tradingsymbol': 'NIFTY2510223950PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 23950.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13449986,
#   'exchange_token': '52539',
#   'tradingsymbol': 'NIFTY2510224000PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 24000.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13488898,
#   'exchange_token': '52691',
#   'tradingsymbol': 'NIFTY2510226500CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 26500.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13490690,
#   'exchange_token': '52698',
#   'tradingsymbol': 'NIFTY2510226500PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 26500.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13488130,
#   'exchange_token': '52688',
#   'tradingsymbol': 'NIFTY2510226450CE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 26450.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'CE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  {'instrument_token': 13488642,
#   'exchange_token': '52690',
#   'tradingsymbol': 'NIFTY2510226450PE',
#   'name': 'NIFTY',
#   'last_price': 0.0,
#   'expiry': datetime.date(2025, 1, 2),
#   'strike': 26450.0,
#   'tick_size': 0.05,
#   'lot_size': 75,
#   'instrument_type': 'PE',
#   'segment': 'NFO-OPT',
#   'exchange': 'NFO'},
#  ...]

# %% [markdown]
# # Instrument

# %%
def fetchInstrumentsFromServer():
    instrumentsList = []
    try:
      brokerHandle = kite_handler
      logging.info('Going to fetch instruments from server...')
      instrumentsList = brokerHandle.instruments('NSE')
      instrumentsListFnO = brokerHandle.instruments('NFO')
      # Add FnO instrument list to the main list
      instrumentsList.extend(instrumentsListFnO)
      logging.info('Fetched %d instruments from server.', len(instrumentsList))
    except Exception as e:
      logging.exception("Exception while fetching instruments from server")
    return instrumentsList

def getInstrumentDataBySymbol(tradingSymbol):
    return Instruments.symbolToInstrumentMap[tradingSymbol]

def getInstrumentDataByToken(instrumentToken):
    return Instruments.tokenToInstrumentMap[instrumentToken]

# %%
Instruments = fetchInstrumentsFromServer()
# Instruments
# Out:
# INFO:root:Going to fetch instruments from server...
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments/NSE HTTP/11" 200 126878
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments/NFO HTTP/11" 200 502858
# INFO:root:Fetched 44724 instruments from server.

# %%
# Creating the map
symbol_to_token = {item['tradingsymbol']: item['instrument_token'] for item in Instruments}
token_to_symbol = {item['instrument_token']: item['tradingsymbol'] for item in Instruments}

# %%
def get_symbol_to_token(tradingsymbol):
    return symbol_to_token.get(tradingsymbol)
def get_token_to_symbol(instrument_token):
    return token_to_symbol.get(instrument_token)

# %%
# Example usage
tradingsymbol = 'NIFTY 50'
get_symbol_to_token(tradingsymbol)
# Out:
# 256265

# %%
instrument_token = 256265
get_token_to_symbol(instrument_token)
# Out:
# 'NIFTY 50'

# %% [markdown]
# # Order Placement

# %%
class KiteConstants:
    #Products
    PRODUCT_MIS = "MIS"
    PRODUCT_CNC = "CNC"
    PRODUCT_NRML = "NRML"
    PRODUCT_CO = "CO"

    # Order types
    ORDER_TYPE_MARKET = "MARKET"
    ORDER_TYPE_LIMIT = "LIMIT"
    ORDER_TYPE_SLM = "SL-M"
    ORDER_TYPE_SL = "SL"

    # Varities
    VARIETY_REGULAR = "regular"
    VARIETY_CO = "co"
    VARIETY_AMO = "amo"
    VARIETY_ICEBERG = "iceberg"
    VARIETY_AUCTION = "auction"

    # Transaction type
    TRANSACTION_TYPE_BUY = "BUY"
    TRANSACTION_TYPE_SELL = "SELL"

    # Validity
    VALIDITY_DAY = "DAY"
    VALIDITY_IOC = "IOC"
    VALIDITY_TTL = "TTL"

    # Position Type
    POSITION_TYPE_DAY = "day"
    POSITION_TYPE_OVERNIGHT = "overnight"

    # Exchanges
    EXCHANGE_NSE = "NSE"
    EXCHANGE_BSE = "BSE"
    EXCHANGE_NFO = "NFO"
    EXCHANGE_CDS = "CDS"
    EXCHANGE_BFO = "BFO"
    EXCHANGE_MCX = "MCX"
    EXCHANGE_BCD = "BCD"

    # Margins segments
    MARGIN_EQUITY = "equity"
    MARGIN_COMMODITY = "commodity"

    # Status constants
    STATUS_COMPLETE = "COMPLETE"
    STATUS_REJECTED = "REJECTED"
    STATUS_CANCELLED = "CANCELLED"

    # GTT order type
    GTT_TYPE_OCO = "two-leg"
    GTT_TYPE_SINGLE = "single"

    # GTT order status
    GTT_STATUS_ACTIVE = "active"
    GTT_STATUS_TRIGGERED = "triggered"
    GTT_STATUS_DISABLED = "disabled"
    GTT_STATUS_EXPIRED = "expired"
    GTT_STATUS_CANCELLED = "cancelled"
    GTT_STATUS_REJECTED = "rejected"
    GTT_STATUS_DELETED = "deleted"

# %%
class OrderState:
    OPEN = "OPEN"
    COMPLETE = "COMPLETE"
    REJECTED = "REJECTED"
    CANCELLED = "CANCELLED"

# %%
class Order:
    def __init__(self, variety, exchange, trading_symbol, transaction_type, quantity, product, order_type, price=None, trigger_price=None):
        self.variety=variety
        self.exchange=exchange
        self.trading_symbol=trading_symbol
        self.transaction_type=transaction_type
        self.quantity=quantity
        self.product=product
        self.order_type=order_type
        self.price=price
        self.trigger_price=trigger_price
        self.average_price=None # Average price at which the order is filled
        self.order_id=None
        self.order_status=None
        self.filled_qty = 0 # Filled quantity
        self.pending_qty = 0 # Pending qty
        self.order_place_timestamp = None # Timestamp when the order is placed
        self.order_timestamp = None # Broker timestamp
        self.exchange_timestamp = None #Exchange timestamp
        self.lastOrderUpdateTimestamp = None # Applicable if you modify the order Ex: Trailing SL
        self.message = None # In case any order rejection or any other error save the response from broker in this field
    
    def set_average_price(self, average_price):
        self.average_price = average_price
    
    def set_order_id(self, order_id):
        self.order_id = order_id
        
    def change_order_status(self, order_status):
        self.order_status = order_status

    def set_filled_qty(self, filled_qty):
        self.filled_qty = filled_qty

    def set_pending_qty(self, pending_qty):
        self.pending_qty = pending_qty

    def set_order_timestamp(self, order_timestamp):
        self.order_timestamp = order_timestamp

    def set_exchange_timestamp(self, exchange_timestamp):
        self.exchange_timestamp = exchange_timestamp

    def set_message(self, message):
        self.message = message

# %%
def placeOrder(order):
    broker = "Zerodha"
    kite = kite_handler
    try:
        order_id = kite.place_order(
        variety=kite.VARIETY_REGULAR,
        exchange=order.exchange,
        tradingsymbol=order.trading_symbol,
        transaction_type=order.transaction_type,
        quantity=order.quantity,
        price=order.price,
        trigger_price=order.trigger_price,
        product=order.product,
        order_type=order.order_type)
        logging.info(f'Order placed successfully, order_id = {order_id}')
        order.set_order_id(order_id)
    except Exception as e:
        logging.info("Order placement failed: {e}")
        raise Exception(str(e))

# %%
try_order = Order(variety=KiteConstants.VARIETY_REGULAR, exchange=KiteConstants.EXCHANGE_NSE, trading_symbol="ITC", transaction_type=KiteConstants.TRANSACTION_TYPE_BUY, quantity=1, product=KiteConstants.PRODUCT_MIS, order_type=KiteConstants.ORDER_TYPE_MARKET)

# %%
try_order_2 = Order(variety=KiteConstants.VARIETY_REGULAR, exchange=KiteConstants.EXCHANGE_NSE, trading_symbol="ITC", transaction_type=KiteConstants.TRANSACTION_TYPE_BUY, quantity=1, product=KiteConstants.PRODUCT_MIS, order_type=KiteConstants.ORDER_TYPE_MARKET)

# %%
placeOrder(try_order)
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/11" 200 None
# INFO:root:Order placed successfully, order_id = 241219201577784

# %%
placeOrder(try_order_2)
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/11" 200 None
# INFO:root:Order placed successfully, order_id = 241219201546167

# %%
try_order_2.order_id
# Out:
# '241219201546167'

# %%
data = {'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201546167', 'exchange_order_id': '1100000042846003', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 13:37:24', 'exchange_update_timestamp': '2024-12-19 13:37:24', 'exchange_timestamp': '2024-12-19 13:37:24', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467, 'filled_quantity': 1, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032XxOepiy817I2E'}
pprint(data)
# Out:
# {'account_id': 'BI3034',
#  'average_price': 467,
#  'cancelled_quantity': 0,
#  'checksum': '',
#  'disclosed_quantity': 0,
#  'exchange': 'NSE',
#  'exchange_order_id': '1100000042846003',
#  'exchange_timestamp': '2024-12-19 13:37:24',
#  'exchange_update_timestamp': '2024-12-19 13:37:24',
#  'filled_quantity': 1,
#  'guid': '130032XxOepiy817I2E',
#  'instrument_token': 424961,
#  'market_protection': 0,
#  'meta': {},
#  'order_id': '241219201546167',
#  'order_timestamp': '2024-12-19 13:37:24',
#  'order_type': 'MARKET',
#  'parent_order_id': None,
#  'pending_quantity': 0,
#  'placed_by': 'BI3034',
#  'price': 0,
#  'product': 'MIS',
#  'quantity': 1,
#  'status': 'COMPLETE',
#  'status_message': None,
#  'status_message_raw': None,
#  'tag': None,
#  'tradingsymbol': 'ITC',
#  'transaction_type': 'BUY',
#  'trigger_price': 0,
#  'unfilled_quantity': 0,
#  'validity': 'DAY',
#  'variety': 'regular'}

# %%
def order_update(ws, data):
    logging.info(data)
    if(try_order.order_id == data['order_id']):
        try_order.set_exchange_timestamp(data['exchange_timestamp'])
        try_order.set_filled_qty(data['filled_quantity'])
        try_order.set_pending_qty(data['pending_quantity'])
        try_order.change_order_status(data['status'])

# %%
kws.on_order_update = order_update

# %%
try_order.order_status
# Out:
# 'COMPLETE'
