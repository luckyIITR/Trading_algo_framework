# %%
import logging
from kiteconnect import KiteConnect
from dotenv import load_dotenv
import os
import json

logging.basicConfig(level=logging.DEBUG)

# Load .env file
load_dotenv("config/.env")

with open("config/zerodha.json", "r") as file:
    config = json.load(file)

class Login:
    def __init__(self):
        self.api_key = os.getenv("api_key")
        self.api_secret = os.getenv("api_secret")
        self.access_token = config['access_token']
        self.kite = KiteConnect(api_key=self.api_key)
        self.kite.set_access_token(self.access_token)
        
        # try to see if token is still valid
        try:
            profile_data = self.kite.profile()
            logging.info(f"User ID: {profile_data['user_id']}, {profile_data['user_name']} Connected!")
        except Exception as e:
            logging.error(f"{e}, Getting new token...")
            self.get_new_token()
        
    def get_new_token(self):
        url = self.kite.login_url()
        print(url)
        request_token = input("Enter Request token: ")
        new_session_data = self.kite.generate_session(request_token=request_token, api_secret=self.api_secret)
        logging.info(f"User ID: {new_session_data['user_id']}, {new_session_data['user_name']} Connected!")
        self.access_token = new_session_data["access_token"]
        self.kite.set_access_token(self.access_token)
        config_data = {
            'access_token' : self.access_token
        }
        with open('config/zerodha.json', 'w') as jsonfile:
            json.dump(config_data, jsonfile, indent=4)
    
    def get_broker_handler(self):
        return self.kite

# %%
import logging
from kiteconnect import KiteTicker
import os
from dotenv import load_dotenv
import json
import time
logging.basicConfig(level=logging.DEBUG)

# Load .env file
load_dotenv("config/.env")

with open("config/zerodha.json", "r") as file:
    config = json.load(file)
    
api_key = os.getenv("api_key")
access_token = config['access_token']

# Initialise
kws = KiteTicker(api_key, access_token)

def on_ticks(ws, ticks):
    # Callback to receive ticks.
    logging.debug("Ticks: {}".format(ticks))

def on_connect(ws, response):
    # Callback on successful connect.
    # Subscribe to a list of instrument_tokens (RELIANCE and ACC here).
    ws.subscribe([738561])

    # Set RELIANCE to tick in `full` mode.
    ws.set_mode(ws.MODE_LTP, [738561])

def on_close(ws, code, reason):
    # On connection close stop the event loop.
    # Reconnection will not happen after executing `ws.stop()`
    print("Connect is closing......")
    ws.stop()

def on_order_update(ws, data):
    # On connection close stop the event loop.
    # Reconnection will not happen after executing `ws.stop()`
    logging.info(f"orderUpdate : {data}")

# Assign the callbacks.
kws.on_ticks = on_ticks
kws.on_connect = on_connect
kws.on_close = on_close
kws.on_order_update = on_order_update

# Infinite loop on the main thread. Nothing after this will run.
# You have to use the pre-defined callbacks to manage subscriptions.
try:
    kws.connect(threaded=True)
except KeyboardInterrupt:
    logging.info("WebSocket connection interrupted by user.")
    kws.stop()
# Out:
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1231.0}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1231.05}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1231.0}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1230.9}]
# DEBUG:root:Ticks: [{'tradable': True, 'mode': 'ltp', 'instrument_token': 738561, 'last_price': 1230.6}]
# INFO:root:orderUpdate : {'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219
 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'SELL', 'validity': 'DAY', 'product': 'MIS', 'quantity': 10, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.35, 'filled_quantity': 9, 'pending_quantity': 1, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '3106Xpioxpjhqwubd'}
# INFO:root:{'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201824025', 'exchange_order_id': '1100000052452485', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 15:01:14', 'exchange_update_timestamp': '2024-12-19 15:01:14', 'exchange_timestamp': '2024-12-19 15:01:14', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'SELL', 'validity': 'DAY', 'product': 'MIS', 'quantity': 10, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467.35, 'filled_quantity': 10, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '3106Xpioxpjhqwubd'}

# %%
kws.unsubscribe([738561])
# Out:
# True

# %%
kws.set_mode(kws.MODE_LTP, [738561])
# Out:
# True

# %%
from pprint import pprint

# %%
obj = Login()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /user/profile HTTP/11" 200 None
# INFO:root:User ID: BI3034, Lucky Kushwaha Connected!

# %%
kite_handler = obj.get_broker_handler()

# %%
data = kite_handler.positions()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /portfolio/positions HTTP/11" 200 None

# %%
data = kite_handler.instruments('NFO')
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments/NFO HTTP/11" 200 516711

# %%
for instu in data:
    if "NIFTY" in instu['tradingsymbol']:
        print(instu['tradingsymbol'])
# Out:
# NIFTY24DECFUT
# NIFTY25JANFUT
# NIFTY25FEBFUT
# BANKNIFTY24DECFUT
# BANKNIFTY25JANFUT
# BANKNIFTY25FEBFUT
# FINNIFTY24DECFUT
# FINNIFTY25JANFUT
# FINNIFTY25FEBFUT
# MIDCPNIFTY24DECFUT
# MIDCPNIFTY25JANFUT
# MIDCPNIFTY25FEBFUT
# NIFTYNXT5024DECFUT
# NIFTYNXT5025JANFUT
# NIFTYNXT5025FEBFUT
# NIFTY24DEC23600CE
# NIFTY24DEC23600PE
# NIFTY24DEC23550CE
# NIFTY24DEC23550PE
# NIFTY24DEC23650CE
# NIFTY24DEC23650PE
# NIFTY24DEC23500CE
# NIFTY24DEC23500PE
# NIFTY24DEC23700CE
# NIFTY24DEC23700PE
# NIFTY24DEC23450CE
# NIFTY24DEC23450PE
# NIFTY24DEC23750CE
# NIFTY24DEC23750PE
# NIFTY24DEC23400CE
# NIFTY24DEC23400PE
# NIFTY24DEC23800CE
# NIFTY24DEC23800PE
# NIFTY24DEC23350CE
# NIFTY24DEC23350PE
# NIFTY24DEC23850CE
# NIFTY24DEC23850PE
# NIFTY24DEC23300CE
# NIFTY24DEC23300PE
# NIFTY24DEC23900CE
# NIFTY24DEC23900PE
# NIFTY24DEC23250CE
# NIFTY24DEC23250PE
# NIFTY24DEC23950CE
# NIFTY24DEC23950PE
# NIFTY24DEC24000PE
# NIFTY24DEC31000CE
# NIFTY24DEC31000PE
# NIFTY24DEC30000CE
# NIFTY24DEC30000PE
# NIFTY24DEC29000CE
# NIFTY24DEC29000PE
# NIFTY24DEC28000CE
# NIFTY24DEC28000PE
# NIFTY24DEC27950CE
# NIFTY24DEC27950PE
# NIFTY24DEC27900CE
# NIFTY24DEC27900PE
# NIFTY24DEC27850CE
# NIFTY24DEC27850PE
# NIFTY24DEC27800CE
# NIFTY24DEC27800PE
# NIFTY24DEC27750CE
# NIFTY24DEC27750PE
# NIFTY24DEC27700CE
# NIFTY24DEC27700PE
# NIFTY24DEC27650CE
# NIFTY24DEC27650PE
# NIFTY24DEC27600CE
# NIFTY24DEC27600PE
# NIFTY24DEC27550CE
# NIFTY24DEC27550PE
# NIFTY24DEC27500CE
# NIFTY24DEC27500PE
# NIFTY24DEC27450CE
# NIFTY24DEC27450PE
# NIFTY24DEC27400CE
# NIFTY24DEC27400PE
# NIFTY24DEC27350CE
# NIFTY24DEC27350PE
# NIFTY24DEC27300CE
# NIFTY24DEC27300PE
# NIFTY24DEC27250CE
# NIFTY24DEC27250PE
# NIFTY24DEC27200CE
# NIFTY24DEC27200PE
# NIFTY24DEC27150CE
# NIFTY24DEC27150PE
# NIFTY24DEC27100CE
# NIFTY24DEC27100PE
# NIFTY24DEC27050CE
# NIFTY24DEC27050PE
# NIFTY24DEC27000CE
# NIFTY24DEC27000PE
# NIFTY24DEC26950CE
# NIFTY24DEC26950PE
# NIFTY24DEC26900CE
# NIFTY24DEC26900PE
# NIFTY24DEC26850CE
# NIFTY24DEC26850PE
# NIFTY24DEC26800CE
# NIFTY24DEC26800PE
# NIFTY24DEC26750CE
# NIFTY24DEC26750PE
# NIFTY24DEC26700CE
# NIFTY24DEC26700PE
# NIFTY24DEC26650CE
# NIFTY24DEC26650PE
# NIFTY24DEC26600CE
# NIFTY24DEC26600PE
# NIFTY24DEC26550CE
# NIFTY24DEC26550PE
# NIFTY24DEC26500CE
# NIFTY24DEC26500PE
# NIFTY24DEC26450CE
# NIFTY24DEC26450PE
# NIFTY24DEC26400CE
# NIFTY24DEC26400PE
# NIFTY24DEC26350CE
# NIFTY24DEC26350PE
# NIFTY24DEC26300CE
# NIFTY24DEC26300PE
# NIFTY24DEC26250CE
# NIFTY24DEC26250PE
# NIFTY24DEC26200CE
# NIFTY24DEC26200PE
# NIFTY24DEC26150CE
# NIFTY24DEC26150PE
# NIFTY24DEC26100CE
# NIFTY24DEC26100PE
# NIFTY24DEC26050CE
# NIFTY24DEC26050PE
# NIFTY24DEC26000CE
# NIFTY24DEC26000PE
# NIFTY24DEC25950CE
# NIFTY24DEC25950PE
# NIFTY24DEC25900CE
# NIFTY24DEC25900PE
# NIFTY24DEC25850CE
# NIFTY24DEC25850PE
# NIFTY24DEC25800CE
# NIFTY24DEC25800PE
# NIFTY24DEC25750CE
# NIFTY24DEC25750PE
# NIFTY24DEC25700CE
# NIFTY24DEC25700PE
# NIFTY24DEC25650CE
# NIFTY24DEC25650PE
# NIFTY24DEC25600CE
# NIFTY24DEC25600PE
# NIFTY24DEC25550CE
# NIFTY24DEC25550PE
# NIFTY24DEC25500CE
# NIFTY24DEC25500PE
# NIFTY24DEC25450CE
# NIFTY24DEC25450PE
# NIFTY24DEC25400CE
# NIFTY24DEC25400PE
# NIFTY24DEC25350CE
# NIFTY24DEC25350PE
# NIFTY24DEC25300CE
# NIFTY24DEC25300PE
# NIFTY24DEC25250CE
# NIFTY24DEC25250PE
# NIFTY24DEC25200CE
# NIFTY24DEC25200PE
# NIFTY24DEC25150CE
# NIFTY24DEC25150PE
# NIFTY24DEC25100CE
# NIFTY24DEC25100PE
# NIFTY24DEC25050CE
# NIFTY24DEC25050PE
# NIFTY24DEC25000CE
# NIFTY24DEC25000PE
# NIFTY24DEC24950CE
# NIFTY24DEC24950PE
# NIFTY24DEC24900CE
# NIFTY24DEC24900PE
# NIFTY24DEC24850CE
# NIFTY24DEC24850PE
# NIFTY24DEC24800CE
# NIFTY24DEC24800PE
# NIFTY24DEC24750CE
# NIFTY24DEC24750PE
# NIFTY24DEC24700CE
# NIFTY24DEC24700PE
# NIFTY24DEC24650CE
# NIFTY24DEC24650PE
# NIFTY24DEC24600CE
# NIFTY24DEC24600PE
# NIFTY24DEC24550CE
# NIFTY24DEC24550PE
# NIFTY24DEC24500CE
# NIFTY24DEC24500PE
# NIFTY24DEC24450CE
# NIFTY24DEC24450PE
# NIFTY24DEC24400CE
# NIFTY24DEC24400PE
# NIFTY24DEC24350CE
# NIFTY24DEC24350PE
# NIFTY24DEC24300CE
# NIFTY24DEC24300PE
# NIFTY24DEC24250CE
# NIFTY24DEC24250PE
# NIFTY24DEC24200CE
# NIFTY24DEC24200PE
# NIFTY24DEC24150CE
# NIFTY24DEC24150PE
# NIFTY24DEC24100CE
# NIFTY24DEC24100PE
# NIFTY24DEC24050CE
# NIFTY24DEC24050PE
# NIFTY24DEC24000CE
# NIFTY24DEC23200CE
# NIFTY24DEC23200PE
# NIFTY24DEC23150CE
# NIFTY24DEC23150PE
# NIFTY24DEC23100CE
# NIFTY24DEC23100PE
# NIFTY24DEC23050CE
# NIFTY24DEC23050PE
# NIFTY24DEC23000CE
# NIFTY24DEC23000PE
# NIFTY24DEC22950CE
# NIFTY24DEC22950PE
# NIFTY24DEC22900CE
# NIFTY24DEC22900PE
# NIFTY24DEC22850CE
# NIFTY24DEC22850PE
# NIFTY24DEC22800CE
# NIFTY24DEC22800PE
# NIFTY24DEC22750CE
# NIFTY24DEC22750PE
# NIFTY24DEC22700CE
# NIFTY24DEC22700PE
# NIFTY24DEC22650CE
# NIFTY24DEC22650PE
# NIFTY24DEC22600CE
# NIFTY24DEC22600PE
# NIFTY24DEC22550CE
# NIFTY24DEC22550PE
# NIFTY24DEC22500CE
# NIFTY24DEC22500PE
# NIFTY24DEC22450CE
# NIFTY24DEC22450PE
# NIFTY24DEC22400CE
# NIFTY24DEC22400PE
# NIFTY24DEC22350CE
# NIFTY24DEC22350PE
# NIFTY24DEC22300CE
# NIFTY24DEC22300PE
# NIFTY24DEC22250CE
# NIFTY24DEC22250PE
# NIFTY24DEC22200CE
# NIFTY24DEC22200PE
# NIFTY24DEC22150CE
# NIFTY24DEC22150PE
# NIFTY24DEC22100CE
# NIFTY24DEC22100PE
# NIFTY24DEC22050CE
# NIFTY24DEC22050PE
# NIFTY24DEC22000CE
# NIFTY24DEC22000PE
# NIFTY24DEC21950CE
# NIFTY24DEC21950PE
# NIFTY24DEC21900CE
# NIFTY24DEC21900PE
# NIFTY24DEC21850CE
# NIFTY24DEC21850PE
# NIFTY24DEC21800CE
# NIFTY24DEC21800PE
# NIFTY24DEC21750CE
# NIFTY24DEC21750PE
# NIFTY24DEC21700CE
# NIFTY24DEC21700PE
# NIFTY24DEC21650CE
# NIFTY24DEC21650PE
# NIFTY24DEC21600CE
# NIFTY24DEC21600PE
# NIFTY24DEC21000CE
# NIFTY24DEC21000PE
# NIFTY24DEC20000CE
# NIFTY24DEC20000PE
# NIFTY24DEC19000CE
# NIFTY24DEC19000PE
# NIFTY24DEC18500CE
# NIFTY24DEC18000CE
# NIFTY24DEC18000PE
# NIFTY24DEC17000CE
# NIFTY24DEC17000PE
# NIFTY24DEC16000CE
# NIFTY24DEC16000PE
# NIFTY24DEC15000CE
# NIFTY24DEC15000PE
# NIFTY24DEC14000CE
# NIFTY24DEC14000PE
# NIFTY2510223600CE
# NIFTY2510223600PE
# NIFTY2510223550CE
# NIFTY2510223550PE
# NIFTY2510223650CE
# NIFTY2510223650PE
# NIFTY2510223500CE
# NIFTY2510223500PE
# NIFTY2510223700CE
# NIFTY2510223700PE
# NIFTY2510223450CE
# NIFTY2510223450PE
# NIFTY2510223750CE
# NIFTY2510223750PE
# NIFTY2510223400CE
# NIFTY2510223400PE
# NIFTY2510223800CE
# NIFTY2510223800PE
# NIFTY2510223350CE
# NIFTY2510223350PE
# NIFTY2510223850CE
# NIFTY2510223850PE
# NIFTY2510223300CE
# NIFTY2510223300PE
# NIFTY2510223900CE
# NIFTY2510223900PE
# NIFTY2510223250CE
# NIFTY2510223250PE
# NIFTY2510223950CE
# NIFTY2510223950PE
# NIFTY2510224000PE
# NIFTY2510226500CE
# NIFTY2510226500PE
# NIFTY2510226450CE
# NIFTY2510226450PE
# NIFTY2510226400CE
# NIFTY2510226400PE
# NIFTY2510226350CE
# NIFTY2510226350PE
# NIFTY2510226300CE
# NIFTY2510226300PE
# NIFTY2510226250CE
# NIFTY2510226250PE
# NIFTY2510226200CE
# NIFTY2510226200PE
# NIFTY2510226150CE
# NIFTY2510226150PE
# NIFTY2510226100CE
# NIFTY2510226100PE
# NIFTY2510226050CE
# NIFTY2510226050PE
# NIFTY2510226000CE
# NIFTY2510226000PE
# NIFTY2510225950CE
# NIFTY2510225950PE
# NIFTY2510225900CE
# NIFTY2510225900PE
# NIFTY2510225850CE
# NIFTY2510225850PE
# NIFTY2510225800CE
# NIFTY2510225800PE
# NIFTY2510225750CE
# NIFTY2510225750PE
# NIFTY2510225700CE
# NIFTY2510225700PE
# NIFTY2510225650CE
# NIFTY2510225650PE
# NIFTY2510225600CE
# NIFTY2510225600PE
# NIFTY2510225550CE
# NIFTY2510225550PE
# NIFTY2510225500CE
# NIFTY2510225500PE
# NIFTY2510225450CE
# NIFTY2510225450PE
# NIFTY2510225400CE
# NIFTY2510225400PE
# NIFTY2510225350CE
# NIFTY2510225350PE
# NIFTY2510225300CE
# NIFTY2510225300PE
# NIFTY2510225250CE
# NIFTY2510225250PE
# NIFTY2510225200CE
# NIFTY2510225200PE
# NIFTY2510225150CE
# NIFTY2510225150PE
# NIFTY2510225100CE
# NIFTY2510225100PE
# NIFTY2510225050CE
# NIFTY2510225050PE
# NIFTY2510225000CE
# NIFTY2510225000PE
# NIFTY2510224950CE
# NIFTY2510224950PE
# NIFTY2510224900CE
# NIFTY2510224900PE
# NIFTY2510224850CE
# NIFTY2510224850PE
# NIFTY2510224800CE
# NIFTY2510224800PE
# NIFTY2510224750CE
# NIFTY2510224750PE
# NIFTY2510224700CE
# NIFTY2510224700PE
# NIFTY2510224650CE
# NIFTY2510224650PE
# NIFTY2510224600CE
# NIFTY2510224600PE
# NIFTY2510224550CE
# NIFTY2510224550PE
# NIFTY2510224500CE
# NIFTY2510224500PE
# NIFTY2510224450CE
# NIFTY2510224450PE
# NIFTY2510224400CE
# NIFTY2510224400PE
# NIFTY2510224350CE
# NIFTY2510224350PE
# NIFTY2510224300CE
# NIFTY2510224300PE
# NIFTY2510224250CE
# NIFTY2510224250PE
# NIFTY2510224200CE
# NIFTY2510224200PE
# NIFTY2510224150CE
# NIFTY2510224150PE
# NIFTY2510224100CE
# NIFTY2510224100PE
# NIFTY2510224050CE
# NIFTY2510224050PE
# NIFTY2510224000CE
# NIFTY2510223200CE
# NIFTY2510223200PE
# NIFTY2510223150CE
# NIFTY2510223150PE
# NIFTY2510223100CE
# NIFTY2510223100PE
# NIFTY2510223050CE
# NIFTY2510223050PE
# NIFTY2510223000CE
# NIFTY2510223000PE
# NIFTY2510222950CE
# NIFTY2510222950PE
# NIFTY2510222900CE
# NIFTY2510222900PE
# NIFTY2510222850CE
# NIFTY2510222850PE
# NIFTY2510222800CE
# NIFTY2510222800PE
# NIFTY2510222750CE
# NIFTY2510222750PE
# NIFTY2510222700CE
# NIFTY2510222700PE
# NIFTY2510222650CE
# NIFTY2510222650PE
# NIFTY2510222600CE
# NIFTY2510222600PE
# NIFTY2510222550CE
# NIFTY2510222550PE
# NIFTY2510222500CE
# NIFTY2510222500PE
# NIFTY2510222450CE
# NIFTY2510222450PE
# NIFTY2510222400CE
# NIFTY2510222400PE
# NIFTY2510222350CE
# NIFTY2510222350PE
# NIFTY2510222300CE
# NIFTY2510222300PE
# NIFTY2510222250CE
# NIFTY2510222250PE
# NIFTY2510222200CE
# NIFTY2510222200PE
# NIFTY2510222150CE
# NIFTY2510222150PE
# NIFTY2510222100CE
# NIFTY2510222100PE
# NIFTY2510222050CE
# NIFTY2510222050PE
# NIFTY2510222000CE
# NIFTY2510222000PE
# NIFTY2510221950CE
# NIFTY2510221950PE
# NIFTY2510221900CE
# NIFTY2510221900PE
# NIFTY2510221850CE
# NIFTY2510221850PE
# NIFTY2510221800CE
# NIFTY2510221800PE
# NIFTY2510221750CE
# NIFTY2510221750PE
# NIFTY2510221700CE
# NIFTY2510221700PE
# NIFTY2510221650CE
# NIFTY2510221650PE
# NIFTY2510221600CE
# NIFTY2510221600PE
# NIFTY2510923600CE
# NIFTY2510923600PE
# NIFTY2510923550CE
# NIFTY2510923550PE
# NIFTY2510923650CE
# NIFTY2510923650PE
# NIFTY2510923500CE
# NIFTY2510923500PE
# NIFTY2510923700CE
# NIFTY2510923700PE
# NIFTY2510923450CE
# NIFTY2510923450PE
# NIFTY2510923750CE
# NIFTY2510923750PE
# NIFTY2510923400CE
# NIFTY2510923400PE
# NIFTY2510923800CE
# NIFTY2510923800PE
# NIFTY2510923350CE
# NIFTY2510923350PE
# NIFTY2510923850CE
# NIFTY2510923850PE
# NIFTY2510923300CE
# NIFTY2510923300PE
# NIFTY2510923900CE
# NIFTY2510923900PE
# NIFTY2510923250CE
# NIFTY2510923250PE
# NIFTY2510923950CE
# NIFTY2510923950PE
# NIFTY2510924000PE
# NIFTY2510926500CE
# NIFTY2510926500PE
# NIFTY2510926450CE
# NIFTY2510926450PE
# NIFTY2510926400CE
# NIFTY2510926400PE
# NIFTY2510926350CE
# NIFTY2510926350PE
# NIFTY2510926300CE
# NIFTY2510926300PE
# NIFTY2510926250CE
# NIFTY2510926250PE
# NIFTY2510926200CE
# NIFTY2510926200PE
# NIFTY2510926150CE
# NIFTY2510926150PE
# NIFTY2510926100CE
# NIFTY2510926100PE
# NIFTY2510926050CE
# NIFTY2510926050PE
# NIFTY2510926000CE
# NIFTY2510926000PE
# NIFTY2510925950CE
# NIFTY2510925950PE
# NIFTY2510925900CE
# NIFTY2510925900PE
# NIFTY2510925850CE
# NIFTY2510925850PE
# NIFTY2510925800CE
# NIFTY2510925800PE
# NIFTY2510925750CE
# NIFTY2510925750PE
# NIFTY2510925700CE
# NIFTY2510925700PE
# NIFTY2510925650CE
# NIFTY2510925650PE
# NIFTY2510925600CE
# NIFTY2510925600PE
# NIFTY2510925550CE
# NIFTY2510925550PE
# NIFTY2510925500CE
# NIFTY2510925500PE
# NIFTY2510925450CE
# NIFTY2510925450PE
# NIFTY2510925400CE
# NIFTY2510925400PE
# NIFTY2510925350CE
# NIFTY2510925350PE
# NIFTY2510925300CE
# NIFTY2510925300PE
# NIFTY2510925250CE
# NIFTY2510925250PE
# NIFTY2510925200CE
# NIFTY2510925200PE
# NIFTY2510925150CE
# NIFTY2510925150PE
# NIFTY2510925100CE
# NIFTY2510925100PE
# NIFTY2510925050CE
# NIFTY2510925050PE
# NIFTY2510925000CE
# NIFTY2510925000PE
# NIFTY2510924950CE
# NIFTY2510924950PE
# NIFTY2510924900CE
# NIFTY2510924900PE
# NIFTY2510924850CE
# NIFTY2510924850PE
# NIFTY2510924800CE
# NIFTY2510924800PE
# NIFTY2510924750CE
# NIFTY2510924750PE
# NIFTY2510924700CE
# NIFTY2510924700PE
# NIFTY2510924650CE
# NIFTY2510924650PE
# NIFTY2510924600CE
# NIFTY2510924600PE
# NIFTY2510924550CE
# NIFTY2510924550PE
# NIFTY2510924500CE
# NIFTY2510924500PE
# NIFTY2510924450CE
# NIFTY2510924450PE
# NIFTY2510924400CE
# NIFTY2510924400PE
# NIFTY2510924350CE
# NIFTY2510924350PE
# NIFTY2510924300CE
# NIFTY2510924300PE
# NIFTY2510924250CE
# NIFTY2510924250PE
# NIFTY2510924200CE
# NIFTY2510924200PE
# NIFTY2510924150CE
# NIFTY2510924150PE
# NIFTY2510924100CE
# NIFTY2510924100PE
# NIFTY2510924050CE
# NIFTY2510924050PE
# NIFTY2510924000CE
# NIFTY2510923200CE
# NIFTY2510923200PE
# NIFTY2510923150CE
# NIFTY2510923150PE
# NIFTY2510923100CE
# NIFTY2510923100PE
# NIFTY2510923050CE
# NIFTY2510923050PE
# NIFTY2510923000CE
# NIFTY2510923000PE
# NIFTY2510922950CE
# NIFTY2510922950PE
# NIFTY2510922900CE
# NIFTY2510922900PE
# NIFTY2510922850CE
# NIFTY2510922850PE
# NIFTY2510922800CE
# NIFTY2510922800PE
# NIFTY2510922750CE
# NIFTY2510922750PE
# NIFTY2510922700CE
# NIFTY2510922700PE
# NIFTY2510922650CE
# NIFTY2510922650PE
# NIFTY2510922600CE
# NIFTY2510922600PE
# NIFTY2510922550CE
# NIFTY2510922550PE
# NIFTY2510922500CE
# NIFTY2510922500PE
# NIFTY2510922450CE
# NIFTY2510922450PE
# NIFTY2510922400CE
# NIFTY2510922400PE
# NIFTY2510922350CE
# NIFTY2510922350PE
# NIFTY2510922300CE
# NIFTY2510922300PE
# NIFTY2510922250CE
# NIFTY2510922250PE
# NIFTY2510922200CE
# NIFTY2510922200PE
# NIFTY2510922150CE
# NIFTY2510922150PE
# NIFTY2510922100CE
# NIFTY2510922100PE
# NIFTY2510922050CE
# NIFTY2510922050PE
# NIFTY2510922000CE
# NIFTY2510922000PE
# NIFTY2510921950CE
# NIFTY2510921950PE
# NIFTY2510921900CE
# NIFTY2510921900PE
# NIFTY2510921850CE
# NIFTY2510921850PE
# NIFTY2511623600CE
# NIFTY2511623600PE
# NIFTY2511623550CE
# NIFTY2511623550PE
# NIFTY2511623650CE
# NIFTY2511623650PE
# NIFTY2511623500CE
# NIFTY2511623500PE
# NIFTY2511623700CE
# NIFTY2511623700PE
# NIFTY2511623450CE
# NIFTY2511623450PE
# NIFTY2511623750CE
# NIFTY2511623750PE
# NIFTY2511623400CE
# NIFTY2511623400PE
# NIFTY2511623800CE
# NIFTY2511623800PE
# NIFTY2511623350CE
# NIFTY2511623350PE
# NIFTY2511623850CE
# NIFTY2511623850PE
# NIFTY2511623300CE
# NIFTY2511623300PE
# NIFTY2511623900CE
# NIFTY2511623900PE
# NIFTY2511623250CE
# NIFTY2511623250PE
# NIFTY2511623950CE
# NIFTY2511623950PE
# NIFTY2511624000PE
# NIFTY2511626500CE
# NIFTY2511626500PE
# NIFTY2511626450CE
# NIFTY2511626450PE
# NIFTY2511626400CE
# NIFTY2511626400PE
# NIFTY2511626350CE
# NIFTY2511626350PE
# NIFTY2511626300CE
# NIFTY2511626300PE
# NIFTY2511626250CE
# NIFTY2511626250PE
# NIFTY2511626200CE
# NIFTY2511626200PE
# NIFTY2511626150CE
# NIFTY2511626150PE
# NIFTY2511626100CE
# NIFTY2511626100PE
# NIFTY2511626050CE
# NIFTY2511626050PE
# NIFTY2511626000CE
# NIFTY2511626000PE
# NIFTY2511625950CE
# NIFTY2511625950PE
# NIFTY2511625900CE
# NIFTY2511625900PE
# NIFTY2511625850CE
# NIFTY2511625850PE
# NIFTY2511625800CE
# NIFTY2511625800PE
# NIFTY2511625750CE
# NIFTY2511625750PE
# NIFTY2511625700CE
# NIFTY2511625700PE
# NIFTY2511625650CE
# NIFTY2511625650PE
# NIFTY2511625600CE
# NIFTY2511625600PE
# NIFTY2511625550CE
# NIFTY2511625550PE
# NIFTY2511625500CE
# NIFTY2511625500PE
# NIFTY2511625450CE
# NIFTY2511625450PE
# NIFTY2511625400CE
# NIFTY2511625400PE
# NIFTY2511625350CE
# NIFTY2511625350PE
# NIFTY2511625300CE
# NIFTY2511625300PE
# NIFTY2511625250CE
# NIFTY2511625250PE
# NIFTY2511625200CE
# NIFTY2511625200PE
# NIFTY2511625150CE
# NIFTY2511625150PE
# NIFTY2511625100CE
# NIFTY2511625100PE
# NIFTY2511625050CE
# NIFTY2511625050PE
# NIFTY2511625000CE
# NIFTY2511625000PE
# NIFTY2511624950CE
# NIFTY2511624950PE
# NIFTY2511624900CE
# NIFTY2511624900PE
# NIFTY2511624850CE
# NIFTY2511624850PE
# NIFTY2511624800CE
# NIFTY2511624800PE
# NIFTY2511624750CE
# NIFTY2511624750PE
# NIFTY2511624700CE
# NIFTY2511624700PE
# NIFTY2511624650CE
# NIFTY2511624650PE
# NIFTY2511624600CE
# NIFTY2511624600PE
# NIFTY2511624550CE
# NIFTY2511624550PE
# NIFTY2511624500CE
# NIFTY2511624500PE
# NIFTY2511624450CE
# NIFTY2511624450PE
# NIFTY2511624400CE
# NIFTY2511624400PE
# NIFTY2511624350CE
# NIFTY2511624350PE
# NIFTY2511624300CE
# NIFTY2511624300PE
# NIFTY2511624250CE
# NIFTY2511624250PE
# NIFTY2511624200CE
# NIFTY2511624200PE
# NIFTY2511624150CE
# NIFTY2511624150PE
# NIFTY2511624100CE
# NIFTY2511624100PE
# NIFTY2511624050CE
# NIFTY2511624050PE
# NIFTY2511624000CE
# NIFTY2511623200CE
# NIFTY2511623200PE
# NIFTY2511623150CE
# NIFTY2511623150PE
# NIFTY2511623100CE
# NIFTY2511623100PE
# NIFTY2511623050CE
# NIFTY2511623050PE
# NIFTY2511623000CE
# NIFTY2511623000PE
# NIFTY2511622950CE
# NIFTY2511622950PE
# NIFTY2511622900CE
# NIFTY2511622900PE
# NIFTY2511622850CE
# NIFTY2511622850PE
# NIFTY2511622800CE
# NIFTY2511622800PE
# NIFTY2511622750CE
# NIFTY2511622750PE
# NIFTY2511622700CE
# NIFTY2511622700PE
# NIFTY2511622650CE
# NIFTY2511622650PE
# NIFTY2511622600CE
# NIFTY2511622600PE
# NIFTY2511622550CE
# NIFTY2511622550PE
# NIFTY2511622500CE
# NIFTY2511622500PE
# NIFTY2511622450CE
# NIFTY2511622450PE
# NIFTY2511622400CE
# NIFTY2511622400PE
# NIFTY2511622350CE
# NIFTY2511622350PE
# NIFTY2511622300CE
# NIFTY2511622300PE
# NIFTY2511622250CE
# NIFTY2511622250PE
# NIFTY2511622200CE
# NIFTY2511622200PE
# NIFTY2511622150CE
# NIFTY2511622150PE
# NIFTY2511622100CE
# NIFTY2511622100PE
# NIFTY2511622050CE
# NIFTY2511622050PE
# NIFTY2511622000CE
# NIFTY2511622000PE
# NIFTY2511621950CE
# NIFTY2511621950PE
# NIFTY2511621900CE
# NIFTY2511621900PE
# NIFTY2511621850CE
# NIFTY2511621850PE
# NIFTY2512323600CE
# NIFTY2512323600PE
# NIFTY2512323550CE
# NIFTY2512323550PE
# NIFTY2512323650CE
# NIFTY2512323650PE
# NIFTY2512323500CE
# NIFTY2512323500PE
# NIFTY2512323700CE
# NIFTY2512323700PE
# NIFTY2512323450CE
# NIFTY2512323450PE
# NIFTY2512323750CE
# NIFTY2512323750PE
# NIFTY2512323400CE
# NIFTY2512323400PE
# NIFTY2512323800CE
# NIFTY2512323800PE
# NIFTY2512323350CE
# NIFTY2512323350PE
# NIFTY2512323850CE
# NIFTY2512323850PE
# NIFTY2512323300CE
# NIFTY2512323300PE
# NIFTY2512323900CE
# NIFTY2512323900PE
# NIFTY2512323250CE
# NIFTY2512323250PE
# NIFTY2512323950CE
# NIFTY2512323950PE
# NIFTY2512324000PE
# NIFTY2512325700CE
# NIFTY2512325700PE
# NIFTY2512325650CE
# NIFTY2512325650PE
# NIFTY2512325600CE
# NIFTY2512325600PE
# NIFTY2512325550CE
# NIFTY2512325550PE
# NIFTY2512325500CE
# NIFTY2512325500PE
# NIFTY2512325450CE
# NIFTY2512325450PE
# NIFTY2512325400CE
# NIFTY2512325400PE
# NIFTY2512325350CE
# NIFTY2512325350PE
# NIFTY2512325300CE
# NIFTY2512325300PE
# NIFTY2512325250CE
# NIFTY2512325250PE
# NIFTY2512325200CE
# NIFTY2512325200PE
# NIFTY2512325150CE
# NIFTY2512325150PE
# NIFTY2512325100CE
# NIFTY2512325100PE
# NIFTY2512325050CE
# NIFTY2512325050PE
# NIFTY2512325000CE
# NIFTY2512325000PE
# NIFTY2512324950CE
# NIFTY2512324950PE
# NIFTY2512324900CE
# NIFTY2512324900PE
# NIFTY2512324850CE
# NIFTY2512324850PE
# NIFTY2512324800CE
# NIFTY2512324800PE
# NIFTY2512324750CE
# NIFTY2512324750PE
# NIFTY2512324700CE
# NIFTY2512324700PE
# NIFTY2512324650CE
# NIFTY2512324650PE
# NIFTY2512324600CE
# NIFTY2512324600PE
# NIFTY2512324550CE
# NIFTY2512324550PE
# NIFTY2512324500CE
# NIFTY2512324500PE
# NIFTY2512324450CE
# NIFTY2512324450PE
# NIFTY2512324400CE
# NIFTY2512324400PE
# NIFTY2512324350CE
# NIFTY2512324350PE
# NIFTY2512324300CE
# NIFTY2512324300PE
# NIFTY2512324250CE
# NIFTY2512324250PE
# NIFTY2512324200CE
# NIFTY2512324200PE
# NIFTY2512324150CE
# NIFTY2512324150PE
# NIFTY2512324100CE
# NIFTY2512324100PE
# NIFTY2512324050CE
# NIFTY2512324050PE
# NIFTY2512324000CE
# NIFTY2512323200CE
# NIFTY2512323200PE
# NIFTY2512323150CE
# NIFTY2512323150PE
# NIFTY2512323100CE
# NIFTY2512323100PE
# NIFTY2512323050CE
# NIFTY2512323050PE
# NIFTY2512323000CE
# NIFTY2512323000PE
# NIFTY2512322950CE
# NIFTY2512322950PE
# NIFTY2512322900CE
# NIFTY2512322900PE
# NIFTY2512322850CE
# NIFTY2512322850PE
# NIFTY2512322800CE
# NIFTY2512322800PE
# NIFTY2512322750CE
# NIFTY2512322750PE
# NIFTY2512322700CE
# NIFTY2512322700PE
# NIFTY2512322650CE
# NIFTY2512322650PE
# NIFTY2512322600CE
# NIFTY2512322600PE
# NIFTY2512322550CE
# NIFTY2512322550PE
# NIFTY2512322500CE
# NIFTY2512322500PE
# NIFTY2512322450CE
# NIFTY2512322450PE
# NIFTY2512322400CE
# NIFTY2512322400PE
# NIFTY2512322350CE
# NIFTY2512322350PE
# NIFTY2512322300CE
# NIFTY2512322300PE
# NIFTY2512322250CE
# NIFTY2512322250PE
# NIFTY2512322200CE
# NIFTY2512322200PE
# NIFTY2512322150CE
# NIFTY2512322150PE
# NIFTY2512322100CE
# NIFTY2512322100PE
# NIFTY2512322050CE
# NIFTY2512322050PE
# NIFTY2512322000CE
# NIFTY2512322000PE
# NIFTY2512321950CE
# NIFTY2512321950PE
# NIFTY2512321900CE
# NIFTY2512321900PE
# NIFTY2512321850CE
# NIFTY2512321850PE
# NIFTY25JAN23600CE
# NIFTY25JAN23600PE
# NIFTY25JAN23550CE
# NIFTY25JAN23550PE
# NIFTY25JAN23650CE
# NIFTY25JAN23650PE
# NIFTY25JAN23500CE
# NIFTY25JAN23500PE
# NIFTY25JAN23700CE
# NIFTY25JAN23700PE
# NIFTY25JAN23450CE
# NIFTY25JAN23450PE
# NIFTY25JAN23750CE
# NIFTY25JAN23750PE
# NIFTY25JAN23400CE
# NIFTY25JAN23400PE
# NIFTY25JAN23800CE
# NIFTY25JAN23800PE
# NIFTY25JAN23350CE
# NIFTY25JAN23350PE
# NIFTY25JAN23850CE
# NIFTY25JAN23850PE
# NIFTY25JAN23300CE
# NIFTY25JAN23300PE
# NIFTY25JAN23900CE
# NIFTY25JAN23900PE
# NIFTY25JAN23250CE
# NIFTY25JAN23250PE
# NIFTY25JAN23950CE
# NIFTY25JAN23950PE
# NIFTY25JAN24000PE
# NIFTY25JAN26500CE
# NIFTY25JAN26500PE
# NIFTY25JAN26450CE
# NIFTY25JAN26450PE
# NIFTY25JAN26400CE
# NIFTY25JAN26400PE
# NIFTY25JAN26350CE
# NIFTY25JAN26350PE
# NIFTY25JAN26300CE
# NIFTY25JAN26300PE
# NIFTY25JAN26250CE
# NIFTY25JAN26250PE
# NIFTY25JAN26200CE
# NIFTY25JAN26200PE
# NIFTY25JAN26150CE
# NIFTY25JAN26150PE
# NIFTY25JAN26100CE
# NIFTY25JAN26100PE
# NIFTY25JAN26050CE
# NIFTY25JAN26050PE
# NIFTY25JAN26000CE
# NIFTY25JAN26000PE
# NIFTY25JAN25950CE
# NIFTY25JAN25950PE
# NIFTY25JAN25900CE
# NIFTY25JAN25900PE
# NIFTY25JAN25850CE
# NIFTY25JAN25850PE
# NIFTY25JAN25800CE
# NIFTY25JAN25800PE
# NIFTY25JAN25750CE
# NIFTY25JAN25750PE
# NIFTY25JAN25700CE
# NIFTY25JAN25700PE
# NIFTY25JAN25650CE
# NIFTY25JAN25650PE
# NIFTY25JAN25600CE
# NIFTY25JAN25600PE
# NIFTY25JAN25550CE
# NIFTY25JAN25550PE
# NIFTY25JAN25500CE
# NIFTY25JAN25500PE
# NIFTY25JAN25450CE
# NIFTY25JAN25450PE
# NIFTY25JAN25400CE
# NIFTY25JAN25400PE
# NIFTY25JAN25350CE
# NIFTY25JAN25350PE
# NIFTY25JAN25300CE
# NIFTY25JAN25300PE
# NIFTY25JAN25250CE
# NIFTY25JAN25250PE
# NIFTY25JAN25200CE
# NIFTY25JAN25200PE
# NIFTY25JAN25150CE
# NIFTY25JAN25150PE
# NIFTY25JAN25100CE
# NIFTY25JAN25100PE
# NIFTY25JAN25050CE
# NIFTY25JAN25050PE
# NIFTY25JAN25000CE
# NIFTY25JAN25000PE
# NIFTY25JAN24950CE
# NIFTY25JAN24950PE
# NIFTY25JAN24900CE
# NIFTY25JAN24900PE
# NIFTY25JAN24850CE
# NIFTY25JAN24850PE
# NIFTY25JAN24800CE
# NIFTY25JAN24800PE
# NIFTY25JAN24750CE
# NIFTY25JAN24750PE
# NIFTY25JAN24700CE
# NIFTY25JAN24700PE
# NIFTY25JAN24650CE
# NIFTY25JAN24650PE
# NIFTY25JAN24600CE
# NIFTY25JAN24600PE
# NIFTY25JAN24550CE
# NIFTY25JAN24550PE
# NIFTY25JAN24500CE
# NIFTY25JAN24500PE
# NIFTY25JAN24450CE
# NIFTY25JAN24450PE
# NIFTY25JAN24400CE
# NIFTY25JAN24400PE
# NIFTY25JAN24350CE
# NIFTY25JAN24350PE
# NIFTY25JAN24300CE
# NIFTY25JAN24300PE
# NIFTY25JAN24250CE
# NIFTY25JAN24250PE
# NIFTY25JAN24200CE
# NIFTY25JAN24200PE
# NIFTY25JAN24150CE
# NIFTY25JAN24150PE
# NIFTY25JAN24100CE
# NIFTY25JAN24100PE
# NIFTY25JAN24050CE
# NIFTY25JAN24050PE
# NIFTY25JAN24000CE
# NIFTY25JAN23200CE
# NIFTY25JAN23200PE
# NIFTY25JAN23150CE
# NIFTY25JAN23150PE
# NIFTY25JAN23100CE
# NIFTY25JAN23100PE
# NIFTY25JAN23050CE
# NIFTY25JAN23050PE
# NIFTY25JAN23000CE
# NIFTY25JAN23000PE
# NIFTY25JAN22950CE
# NIFTY25JAN22950PE
# NIFTY25JAN22900CE
# NIFTY25JAN22900PE
# NIFTY25JAN22850CE
# NIFTY25JAN22850PE
# NIFTY25JAN22800CE
# NIFTY25JAN22800PE
# NIFTY25JAN22750CE
# NIFTY25JAN22750PE
# NIFTY25JAN22700CE
# NIFTY25JAN22700PE
# NIFTY25JAN22650CE
# NIFTY25JAN22650PE
# NIFTY25JAN22600CE
# NIFTY25JAN22600PE
# NIFTY25JAN22550CE
# NIFTY25JAN22550PE
# NIFTY25JAN22500CE
# NIFTY25JAN22500PE
# NIFTY25JAN22450CE
# NIFTY25JAN22450PE
# NIFTY25JAN22400CE
# NIFTY25JAN22400PE
# NIFTY25JAN22350CE
# NIFTY25JAN22350PE
# NIFTY25JAN22300CE
# NIFTY25JAN22300PE
# NIFTY25JAN22250CE
# NIFTY25JAN22250PE
# NIFTY25JAN22200CE
# NIFTY25JAN22200PE
# NIFTY25JAN22150CE
# NIFTY25JAN22150PE
# NIFTY25JAN22100CE
# NIFTY25JAN22100PE
# NIFTY25JAN22050CE
# NIFTY25JAN22050PE
# NIFTY25JAN22000CE
# NIFTY25JAN22000PE
# NIFTY25JAN21950CE
# NIFTY25JAN21950PE
# NIFTY25JAN21900CE
# NIFTY25JAN21900PE
# NIFTY25JAN21850CE
# NIFTY25JAN21850PE
# NIFTY25JAN21800CE
# NIFTY25JAN21800PE
# NIFTY25JAN21750CE
# NIFTY25JAN21750PE
# NIFTY25JAN21700CE
# NIFTY25JAN21700PE
# NIFTY25JAN21650CE
# NIFTY25JAN21650PE
# NIFTY25JAN21600CE
# NIFTY25JAN21600PE
# NIFTY25FEB23600CE
# NIFTY25FEB23600PE
# NIFTY25FEB23550CE
# NIFTY25FEB23550PE
# NIFTY25FEB23650CE
# NIFTY25FEB23650PE
# NIFTY25FEB23500CE
# NIFTY25FEB23500PE
# NIFTY25FEB23700CE
# NIFTY25FEB23700PE
# NIFTY25FEB23450CE
# NIFTY25FEB23450PE
# NIFTY25FEB23750CE
# NIFTY25FEB23750PE
# NIFTY25FEB23400CE
# NIFTY25FEB23400PE
# NIFTY25FEB23800CE
# NIFTY25FEB23800PE
# NIFTY25FEB23350CE
# NIFTY25FEB23350PE
# NIFTY25FEB23850CE
# NIFTY25FEB23850PE
# NIFTY25FEB23300CE
# NIFTY25FEB23300PE
# NIFTY25FEB23900CE
# NIFTY25FEB23900PE
# NIFTY25FEB23250CE
# NIFTY25FEB23250PE
# NIFTY25FEB23950CE
# NIFTY25FEB23950PE
# NIFTY25FEB24000PE
# NIFTY25FEB26500CE
# NIFTY25FEB26500PE
# NIFTY25FEB26450CE
# NIFTY25FEB26450PE
# NIFTY25FEB26400CE
# NIFTY25FEB26400PE
# NIFTY25FEB26350CE
# NIFTY25FEB26350PE
# NIFTY25FEB26300CE
# NIFTY25FEB26300PE
# NIFTY25FEB26250CE
# NIFTY25FEB26250PE
# NIFTY25FEB26200CE
# NIFTY25FEB26200PE
# NIFTY25FEB26150CE
# NIFTY25FEB26150PE
# NIFTY25FEB26100CE
# NIFTY25FEB26100PE
# NIFTY25FEB26050CE
# NIFTY25FEB26050PE
# NIFTY25FEB26000CE
# NIFTY25FEB22650CE
# NIFTY25FEB22650PE
# NIFTY25FEB22600CE
# NIFTY25FEB22600PE
# NIFTY25FEB22550CE
# NIFTY25FEB22550PE
# NIFTY25FEB22500CE
# NIFTY25FEB22500PE
# NIFTY25FEB22450CE
# NIFTY25FEB22450PE
# NIFTY25FEB22400CE
# NIFTY25FEB22400PE
# NIFTY25FEB22350CE
# NIFTY25FEB22350PE
# NIFTY25FEB22300CE
# NIFTY25FEB22300PE
# NIFTY25FEB22250CE
# NIFTY25FEB22250PE
# NIFTY25FEB22200CE
# NIFTY25FEB22200PE
# NIFTY25FEB22150CE
# NIFTY25FEB22150PE
# NIFTY25FEB22100CE
# NIFTY25FEB22100PE
# NIFTY25FEB22050CE
# NIFTY25FEB22050PE
# NIFTY25FEB22000CE
# NIFTY25FEB22000PE
# NIFTY25FEB21950CE
# NIFTY25FEB21950PE
# NIFTY25FEB21900CE
# NIFTY25FEB21900PE
# NIFTY25FEB21850CE
# NIFTY25FEB21850PE
# NIFTY25MAR24000CE
# NIFTY25MAR24000PE
# NIFTY25MAR23000CE
# NIFTY25MAR23000PE
# NIFTY25MAR25000CE
# NIFTY25MAR25000PE
# NIFTY25MAR22000CE
# NIFTY25MAR22000PE
# NIFTY25MAR26000CE
# NIFTY25MAR26000PE
# NIFTY25MAR21000CE
# NIFTY25MAR21000PE
# NIFTY25MAR27000CE
# NIFTY25MAR27000PE
# NIFTY25MAR20000CE
# NIFTY25MAR20000PE
# NIFTY25MAR28000CE
# NIFTY25MAR28000PE
# NIFTY25MAR19000CE
# NIFTY25MAR19000PE
# NIFTY25MAR29000CE
# NIFTY25MAR29000PE
# NIFTY25MAR18000CE
# NIFTY25MAR18000PE
# NIFTY25MAR30000CE
# NIFTY25MAR30000PE
# NIFTY25MAR31000CE
# NIFTY25MAR31000PE
# NIFTY25JUN24000CE
# NIFTY25JUN24000PE
# NIFTY25JUN23000CE
# NIFTY25JUN23000PE
# NIFTY25JUN25000CE
# NIFTY25JUN25000PE
# NIFTY25JUN22000CE
# NIFTY25JUN22000PE
# NIFTY25JUN26000CE
# NIFTY25JUN26000PE
# NIFTY25JUN21000CE
# NIFTY25JUN21000PE
# NIFTY25JUN27000CE
# NIFTY25JUN27000PE
# NIFTY25JUN20000CE
# NIFTY25JUN20000PE
# NIFTY25JUN28000CE
# NIFTY25JUN28000PE
# NIFTY25JUN19000CE
# NIFTY25JUN19000PE
# NIFTY25JUN29000CE
# NIFTY25JUN29000PE
# NIFTY25JUN18000CE
# NIFTY25JUN18000PE
# NIFTY25JUN30000CE
# NIFTY25JUN30000PE
# NIFTY25JUN17000CE
# NIFTY25JUN31000CE
# NIFTY25JUN31000PE
# NIFTY25JUN16000PE
# NIFTY25JUN15000PE
# NIFTY25JUN14000PE
# NIFTY25SEP18000CE
# NIFTY25SEP18000PE
# NIFTY25SEP19000CE
# NIFTY25SEP19000PE
# NIFTY25SEP20000CE
# NIFTY25SEP20000PE
# NIFTY25SEP21000CE
# NIFTY25SEP21000PE
# NIFTY25SEP22000CE
# NIFTY25SEP22000PE
# NIFTY25SEP23000CE
# NIFTY25SEP23000PE
# NIFTY25SEP24000CE
# NIFTY25SEP24000PE
# NIFTY25SEP25000CE
# NIFTY25SEP25000PE
# NIFTY25SEP26000CE
# NIFTY25SEP26000PE
# NIFTY25SEP27000CE
# NIFTY25SEP27000PE
# NIFTY25SEP28000CE
# NIFTY25SEP28000PE
# NIFTY25SEP29000CE
# NIFTY25SEP29000PE
# NIFTY25SEP30000CE
# NIFTY25SEP30000PE
# NIFTY25SEP31000CE
# NIFTY25SEP31000PE
# NIFTY25DEC24000CE
# NIFTY25DEC24000PE
# NIFTY25DEC23000CE
# NIFTY25DEC23000PE
# NIFTY25DEC25000CE
# NIFTY25DEC25000PE
# NIFTY25DEC22000CE
# NIFTY25DEC22000PE
# NIFTY25DEC26000CE
# NIFTY25DEC26000PE
# NIFTY25DEC21000CE
# NIFTY25DEC21000PE
# NIFTY25DEC27000CE
# NIFTY25DEC27000PE
# NIFTY25DEC20000CE
# NIFTY25DEC20000PE
# NIFTY25DEC19500CE
# NIFTY25DEC28000CE
# NIFTY25DEC28000PE
# NIFTY25DEC19000CE
# NIFTY25DEC19000PE
# NIFTY25DEC29000CE
# NIFTY25DEC29000PE
# NIFTY25DEC18000CE
# NIFTY25DEC18000PE
# NIFTY25DEC30000CE
# NIFTY25DEC30000PE
# NIFTY25DEC17000CE
# NIFTY25DEC31000CE
# NIFTY25DEC31000PE
# NIFTY25DEC17000PE
# NIFTY25DEC16500PE
# NIFTY25DEC16000CE
# NIFTY25DEC16000PE
# NIFTY25DEC15000PE
# NIFTY25DEC13000PE
# NIFTY26JUN24000CE
# NIFTY26JUN24000PE
# NIFTY26JUN23000CE
# NIFTY26JUN23000PE
# NIFTY26JUN25000CE
# NIFTY26JUN25000PE
# NIFTY26JUN22000CE
# NIFTY26JUN22000PE
# NIFTY26JUN26000CE
# NIFTY26JUN26000PE
# NIFTY26JUN21000CE
# NIFTY26JUN21000PE
# NIFTY26JUN27000CE
# NIFTY26JUN27000PE
# NIFTY26JUN20000CE
# NIFTY26JUN20000PE
# NIFTY26JUN28000CE
# NIFTY26JUN28000PE
# NIFTY26JUN19000CE
# NIFTY26JUN19000PE
# NIFTY26JUN29000CE
# NIFTY26JUN29000PE
# NIFTY26JUN18000CE
# NIFTY26JUN18000PE
# NIFTY26JUN30000CE
# NIFTY26JUN30000PE
# NIFTY26JUN31000CE
# NIFTY26JUN31000PE
# NIFTY26JUN16000PE
# NIFTY26JUN15000PE
# NIFTY26JUN14000PE
# NIFTY26JUN13000PE
# NIFTY26JUN12000CE
# NIFTY26JUN12000PE
# NIFTY26DEC24000CE
# NIFTY26DEC24000PE
# NIFTY26DEC23000CE
# NIFTY26DEC23000PE
# NIFTY26DEC25000CE
# NIFTY26DEC25000PE
# NIFTY26DEC22000CE
# NIFTY26DEC22000PE
# NIFTY26DEC26000CE
# NIFTY26DEC26000PE
# NIFTY26DEC21000CE
# NIFTY26DEC21000PE
# NIFTY26DEC27000CE
# NIFTY26DEC27000PE
# NIFTY26DEC20000CE
# NIFTY26DEC20000PE
# NIFTY26DEC28000CE
# NIFTY26DEC28000PE
# NIFTY26DEC19000CE
# NIFTY26DEC19000PE
# NIFTY26DEC29000CE
# NIFTY26DEC29000PE
# NIFTY26DEC18000CE
# NIFTY26DEC18000PE
# NIFTY26DEC30000CE
# NIFTY26DEC30000PE
# NIFTY26DEC17000PE
# NIFTY26DEC31000CE
# NIFTY26DEC31000PE
# NIFTY26DEC16000CE
# NIFTY26DEC16000PE
# NIFTY26DEC15000PE
# NIFTY26DEC14000PE
# NIFTY26DEC13000PE
# NIFTY26DEC12000PE
# NIFTY27JUN30000CE
# NIFTY27JUN30000PE
# NIFTY27JUN29000CE
# NIFTY27JUN29000PE
# NIFTY27JUN31000CE
# NIFTY27JUN31000PE
# NIFTY27JUN28000CE
# NIFTY27JUN28000PE
# NIFTY27JUN27000CE
# NIFTY27JUN27000PE
# NIFTY27JUN18000CE
# NIFTY27JUN18000PE
# NIFTY27JUN19000CE
# NIFTY27JUN19000PE
# NIFTY27JUN20000CE
# NIFTY27JUN20000PE
# NIFTY27JUN21000CE
# NIFTY27JUN21000PE
# NIFTY27JUN22000CE
# NIFTY27JUN22000PE
# NIFTY27JUN23000CE
# NIFTY27JUN23000PE
# NIFTY27JUN24000CE
# NIFTY27JUN24000PE
# NIFTY27JUN25000CE
# NIFTY27JUN25000PE
# NIFTY27JUN26000CE
# NIFTY27JUN26000PE
# NIFTY27DEC24000CE
# NIFTY27DEC24000PE
# NIFTY27DEC23000CE
# NIFTY27DEC23000PE
# NIFTY27DEC25000CE
# NIFTY27DEC25000PE
# NIFTY27DEC22000CE
# NIFTY27DEC22000PE
# NIFTY27DEC26000CE
# NIFTY27DEC26000PE
# NIFTY27DEC21000CE
# NIFTY27DEC21000PE
# NIFTY27DEC27000CE
# NIFTY27DEC27000PE
# NIFTY27DEC20000CE
# NIFTY27DEC20000PE
# NIFTY27DEC28000CE
# NIFTY27DEC28000PE
# NIFTY27DEC19000CE
# NIFTY27DEC19000PE
# NIFTY27DEC29000CE
# NIFTY27DEC29000PE
# NIFTY27DEC18000CE
# NIFTY27DEC18000PE
# NIFTY27DEC30000CE
# NIFTY27DEC30000PE
# NIFTY27DEC17000PE
# NIFTY27DEC31000CE
# NIFTY27DEC31000PE
# NIFTY27DEC15000PE
# NIFTY28JUN30000CE
# NIFTY28JUN30000PE
# NIFTY28JUN31000CE
# NIFTY28JUN31000PE
# NIFTY28JUN18000CE
# NIFTY28JUN18000PE
# NIFTY28JUN19000CE
# NIFTY28JUN19000PE
# NIFTY28JUN20000CE
# NIFTY28JUN20000PE
# NIFTY28JUN21000CE
# NIFTY28JUN21000PE
# NIFTY28JUN22000CE
# NIFTY28JUN22000PE
# NIFTY28JUN23000CE
# NIFTY28JUN23000PE
# NIFTY28JUN24000CE
# NIFTY28JUN24000PE
# NIFTY28JUN25000CE
# NIFTY28JUN25000PE
# NIFTY28JUN26000CE
# NIFTY28JUN26000PE
# NIFTY28JUN27000CE
# NIFTY28JUN27000PE
# NIFTY28JUN28000CE
# NIFTY28JUN28000PE
# NIFTY28JUN29000CE
# NIFTY28JUN29000PE
# NIFTY28DEC24000CE
# NIFTY28DEC24000PE
# NIFTY28DEC23000CE
# NIFTY28DEC23000PE
# NIFTY28DEC25000CE
# NIFTY28DEC25000PE
# NIFTY28DEC22000CE
# NIFTY28DEC22000PE
# NIFTY28DEC26000CE
# NIFTY28DEC26000PE
# NIFTY28DEC21000CE
# NIFTY28DEC21000PE
# NIFTY28DEC27000CE
# NIFTY28DEC27000PE
# NIFTY28DEC20000CE
# NIFTY28DEC20000PE
# NIFTY28DEC28000CE
# NIFTY28DEC28000PE
# NIFTY28DEC19000CE
# NIFTY28DEC19000PE
# NIFTY28DEC29000CE
# NIFTY28DEC29000PE
# NIFTY28DEC18000CE
# NIFTY28DEC18000PE
# NIFTY28DEC30000CE
# NIFTY28DEC30000PE
# NIFTY28DEC31000CE
# NIFTY28DEC31000PE
# NIFTY29JUN18000CE
# NIFTY29JUN18000PE
# NIFTY29JUN19000CE
# NIFTY29JUN19000PE
# NIFTY29JUN20000CE
# NIFTY29JUN20000PE
# NIFTY29JUN21000CE
# NIFTY29JUN21000PE
# NIFTY29JUN22000CE
# NIFTY29JUN22000PE
# NIFTY29JUN23000CE
# NIFTY29JUN23000PE
# NIFTY29JUN24000CE
# NIFTY29JUN24000PE
# NIFTY29JUN25000CE
# NIFTY29JUN25000PE
# NIFTY29JUN26000CE
# NIFTY29JUN26000PE
# NIFTY29JUN27000CE
# NIFTY29JUN27000PE
# NIFTY29JUN28000CE
# NIFTY29JUN28000PE
# NIFTY29JUN29000CE
# NIFTY29JUN29000PE
# NIFTY29JUN30000CE
# NIFTY29JUN30000PE
# NIFTY29JUN31000CE
# NIFTY29JUN31000PE
# BANKNIFTY24DEC50800CE
# BANKNIFTY24DEC50800PE
# BANKNIFTY24DEC50700CE
# BANKNIFTY24DEC50700PE
# BANKNIFTY24DEC50900CE
# BANKNIFTY24DEC50900PE
# BANKNIFTY24DEC50600CE
# BANKNIFTY24DEC50600PE
# BANKNIFTY24DEC51000CE
# BANKNIFTY24DEC51000PE
# BANKNIFTY24DEC50500CE
# BANKNIFTY24DEC50500PE
# BANKNIFTY24DEC51100CE
# BANKNIFTY24DEC51100PE
# BANKNIFTY24DEC50400CE
# BANKNIFTY24DEC50400PE
# BANKNIFTY24DEC51200CE
# BANKNIFTY24DEC51200PE
# BANKNIFTY24DEC50300CE
# BANKNIFTY24DEC50300PE
# BANKNIFTY24DEC51300CE
# BANKNIFTY24DEC51300PE
# BANKNIFTY24DEC50200CE
# BANKNIFTY24DEC50200PE
# BANKNIFTY24DEC51400CE
# BANKNIFTY24DEC51400PE
# BANKNIFTY24DEC50100CE
# BANKNIFTY24DEC50100PE
# BANKNIFTY24DEC51500CE
# BANKNIFTY24DEC51500PE
# BANKNIFTY25MAR55500CE
# BANKNIFTY25MAR55500PE
# BANKNIFTY25MAR45000CE
# BANKNIFTY25MAR45000PE
# BANKNIFTY25MAR57000CE
# BANKNIFTY25MAR57000PE
# BANKNIFTY25MAR43500CE
# BANKNIFTY25MAR43500PE
# BANKNIFTY25MAR58500CE
# BANKNIFTY25MAR58500PE
# BANKNIFTY25MAR42000CE
# BANKNIFTY25MAR42000PE
# BANKNIFTY25MAR60000CE
# BANKNIFTY25MAR60000PE
# BANKNIFTY25MAR61500CE
# BANKNIFTY25MAR61500PE
# BANKNIFTY25JUN51000CE
# BANKNIFTY25JUN51000PE
# BANKNIFTY25JUN49500CE
# BANKNIFTY25JUN49500PE
# BANKNIFTY25JUN52500CE
# BANKNIFTY25JUN52500PE
# BANKNIFTY25JUN48000CE
# BANKNIFTY25JUN48000PE
# BANKNIFTY25JUN54000CE
# BANKNIFTY25JUN54000PE
# BANKNIFTY25JUN46500CE
# BANKNIFTY25JUN46500PE
# BANKNIFTY25JUN55500CE
# BANKNIFTY25JUN55500PE
# BANKNIFTY25JUN45000CE
# BANKNIFTY25JUN45000PE
# BANKNIFTY25JUN57000CE
# BANKNIFTY25JUN57000PE
# BANKNIFTY25JUN43500CE
# BANKNIFTY25JUN43500PE
# BANKNIFTY25JUN58500CE
# BANKNIFTY25JUN58500PE
# BANKNIFTY25JUN42000CE
# BANKNIFTY25JUN42000PE
# BANKNIFTY25JUN60000CE
# BANKNIFTY25JUN60000PE
# BANKNIFTY25JUN61500CE
# BANKNIFTY25JUN61500PE
# BANKNIFTY25SEP42000CE
# BANKNIFTY25SEP42000PE
# ...
# NIFTYNXT5024DEC63700PE
# NIFTYNXT5024DEC63600CE
# NIFTYNXT5024DEC63600PE
# NIFTYNXT5024DEC63500CE
# NIFTYNXT5024DEC63500PE
# NIFTYNXT5024DEC63400CE
# NIFTYNXT5024DEC63400PE
# NIFTYNXT5024DEC63300CE
# NIFTYNXT5024DEC63300PE
# NIFTYNXT5024DEC63200CE
# NIFTYNXT5024DEC63200PE
# NIFTYNXT5024DEC63100CE
# NIFTYNXT5024DEC63100PE
# NIFTYNXT5024DEC63000CE
# NIFTYNXT5024DEC63000PE
# NIFTYNXT5024DEC62900CE
# NIFTYNXT5024DEC62900PE
# NIFTYNXT5024DEC62800CE
# NIFTYNXT5024DEC62800PE
# NIFTYNXT5024DEC62700CE
# NIFTYNXT5024DEC62700PE
# NIFTYNXT5024DEC62500CE
# NIFTYNXT5024DEC62500PE
# NIFTYNXT5024DEC62000CE
# NIFTYNXT5024DEC62000PE
# NIFTYNXT5024DEC61500CE
# NIFTYNXT5024DEC61500PE
# NIFTYNXT5024DEC61000CE
# NIFTYNXT5024DEC61000PE
# NIFTYNXT5024DEC60500CE
# NIFTYNXT5024DEC60500PE
# NIFTYNXT5024DEC60000CE
# NIFTYNXT5024DEC60000PE
# NIFTYNXT5024DEC59500CE
# NIFTYNXT5024DEC59500PE
# NIFTYNXT5024DEC59000CE
# NIFTYNXT5025JAN73100CE
# NIFTYNXT5025JAN73100PE
# NIFTYNXT5025JAN73200CE
# NIFTYNXT5025JAN73200PE
# NIFTYNXT5025JAN73300CE
# NIFTYNXT5025JAN73300PE
# NIFTYNXT5025JAN73400CE
# NIFTYNXT5025JAN73400PE
# NIFTYNXT5025JAN73500CE
# NIFTYNXT5025JAN73500PE
# NIFTYNXT5025JAN73600CE
# NIFTYNXT5025JAN73600PE
# NIFTYNXT5025JAN73700CE
# NIFTYNXT5025JAN73700PE
# NIFTYNXT5025JAN73800CE
# NIFTYNXT5025JAN73800PE
# NIFTYNXT5025JAN73900CE
# NIFTYNXT5025JAN73900PE
# NIFTYNXT5025JAN74000CE
# NIFTYNXT5025JAN74000PE
# NIFTYNXT5025JAN74100CE
# NIFTYNXT5025JAN74100PE
# NIFTYNXT5025JAN74200CE
# NIFTYNXT5025JAN74200PE
# NIFTYNXT5025JAN74300CE
# NIFTYNXT5025JAN74300PE
# NIFTYNXT5025JAN74400CE
# NIFTYNXT5025JAN74400PE
# NIFTYNXT5025JAN74500CE
# NIFTYNXT5025JAN74500PE
# NIFTYNXT5025JAN74600CE
# NIFTYNXT5025JAN74600PE
# NIFTYNXT5025JAN74700CE
# NIFTYNXT5025JAN74700PE
# NIFTYNXT5025JAN74800CE
# NIFTYNXT5025JAN74800PE
# NIFTYNXT5025JAN74900CE
# NIFTYNXT5025JAN74900PE
# NIFTYNXT5025JAN75000CE
# NIFTYNXT5025JAN75000PE
# NIFTYNXT5025JAN75100CE
# NIFTYNXT5025JAN75100PE
# NIFTYNXT5025JAN75200CE
# NIFTYNXT5025JAN75200PE
# NIFTYNXT5025JAN75300CE
# NIFTYNXT5025JAN75300PE
# NIFTYNXT5025JAN75400CE
# NIFTYNXT5025JAN75400PE
# NIFTYNXT5025JAN75500CE
# NIFTYNXT5025JAN75500PE
# NIFTYNXT5025JAN75600CE
# NIFTYNXT5025JAN75600PE
# NIFTYNXT5025JAN75700CE
# NIFTYNXT5025JAN75700PE
# NIFTYNXT5025JAN75800CE
# NIFTYNXT5025JAN75800PE
# NIFTYNXT5025JAN75900CE
# NIFTYNXT5025JAN75900PE
# NIFTYNXT5025JAN76000CE
# NIFTYNXT5025JAN76000PE
# NIFTYNXT5025JAN76100CE
# NIFTYNXT5025JAN76100PE
# NIFTYNXT5025JAN76200CE
# NIFTYNXT5025JAN76200PE
# NIFTYNXT5025JAN76300CE
# NIFTYNXT5025JAN76300PE
# NIFTYNXT5025JAN76400CE
# NIFTYNXT5025JAN76400PE
# NIFTYNXT5025JAN76500CE
# NIFTYNXT5025JAN76500PE
# NIFTYNXT5025JAN76600CE
# NIFTYNXT5025JAN76600PE
# NIFTYNXT5025JAN76700CE
# NIFTYNXT5025JAN76700PE
# NIFTYNXT5025JAN76800CE
# NIFTYNXT5025JAN76800PE
# NIFTYNXT5025JAN76900CE
# NIFTYNXT5025JAN76900PE
# NIFTYNXT5025JAN77000CE
# NIFTYNXT5025JAN77000PE
# NIFTYNXT5025FEB62500CE
# NIFTYNXT5025FEB62500PE
# NIFTYNXT5025FEB62000CE
# NIFTYNXT5025FEB62000PE
# NIFTYNXT5025FEB61500CE
# NIFTYNXT5025FEB61500PE
# NIFTYNXT5025FEB61000CE
# NIFTYNXT5025FEB61000PE
# NIFTYNXT5025FEB60500CE
# NIFTYNXT5025FEB60500PE
# NIFTYNXT5025FEB60000CE
# NIFTYNXT5025FEB60000PE
# NIFTYNXT5025FEB59500CE
# NIFTYNXT5025FEB59500PE
# NIFTYNXT5025FEB59000CE
# NIFTYNXT5025FEB59000PE
# NIFTYNXT5025FEB58500CE
# NIFTYNXT5025FEB58500PE

# %% [markdown]
# # Instrument

# %%
def fetchInstrumentsFromServer():
    instrumentsList = []
    try:
      brokerHandle = kite_handler
      logging.info('Going to fetch instruments from server...')
      instrumentsList = brokerHandle.instruments('NSE')
      instrumentsListFnO = brokerHandle.instruments('NFO')
      # Add FnO instrument list to the main list
      instrumentsList.extend(instrumentsListFnO)
      logging.info('Fetched %d instruments from server.', len(instrumentsList))
    except Exception as e:
      logging.exception("Exception while fetching instruments from server")
    return instrumentsList

def getInstrumentDataBySymbol(tradingSymbol):
    return Instruments.symbolToInstrumentMap[tradingSymbol]

def getInstrumentDataByToken(instrumentToken):
    return Instruments.tokenToInstrumentMap[instrumentToken]

# %%
Instruments = fetchInstrumentsFromServer()
# Instruments
# Out:
# INFO:root:Going to fetch instruments from server...
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments/NSE HTTP/11" 200 126878
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments/NFO HTTP/11" 200 502858
# INFO:root:Fetched 44724 instruments from server.

# %%
# Creating the map
symbol_to_token = {item['tradingsymbol']: item['instrument_token'] for item in Instruments}
token_to_symbol = {item['instrument_token']: item['tradingsymbol'] for item in Instruments}

# %%
def get_symbol_to_token(tradingsymbol):
    return symbol_to_token.get(tradingsymbol)
def get_token_to_symbol(instrument_token):
    return token_to_symbol.get(instrument_token)

# %%
# Example usage
tradingsymbol = 'NIFTY 50'
get_symbol_to_token(tradingsymbol)
# Out:
# 256265

# %%
instrument_token = 256265
get_token_to_symbol(instrument_token)
# Out:
# 'NIFTY 50'

# %% [markdown]
# # Order Placement

# %%
class KiteConstants:
    #Products
    PRODUCT_MIS = "MIS"
    PRODUCT_CNC = "CNC"
    PRODUCT_NRML = "NRML"
    PRODUCT_CO = "CO"

    # Order types
    ORDER_TYPE_MARKET = "MARKET"
    ORDER_TYPE_LIMIT = "LIMIT"
    ORDER_TYPE_SLM = "SL-M"
    ORDER_TYPE_SL = "SL"

    # Varities
    VARIETY_REGULAR = "regular"
    VARIETY_CO = "co"
    VARIETY_AMO = "amo"
    VARIETY_ICEBERG = "iceberg"
    VARIETY_AUCTION = "auction"

    # Transaction type
    TRANSACTION_TYPE_BUY = "BUY"
    TRANSACTION_TYPE_SELL = "SELL"

    # Validity
    VALIDITY_DAY = "DAY"
    VALIDITY_IOC = "IOC"
    VALIDITY_TTL = "TTL"

    # Position Type
    POSITION_TYPE_DAY = "day"
    POSITION_TYPE_OVERNIGHT = "overnight"

    # Exchanges
    EXCHANGE_NSE = "NSE"
    EXCHANGE_BSE = "BSE"
    EXCHANGE_NFO = "NFO"
    EXCHANGE_CDS = "CDS"
    EXCHANGE_BFO = "BFO"
    EXCHANGE_MCX = "MCX"
    EXCHANGE_BCD = "BCD"

    # Margins segments
    MARGIN_EQUITY = "equity"
    MARGIN_COMMODITY = "commodity"

    # Status constants
    STATUS_COMPLETE = "COMPLETE"
    STATUS_REJECTED = "REJECTED"
    STATUS_CANCELLED = "CANCELLED"

    # GTT order type
    GTT_TYPE_OCO = "two-leg"
    GTT_TYPE_SINGLE = "single"

    # GTT order status
    GTT_STATUS_ACTIVE = "active"
    GTT_STATUS_TRIGGERED = "triggered"
    GTT_STATUS_DISABLED = "disabled"
    GTT_STATUS_EXPIRED = "expired"
    GTT_STATUS_CANCELLED = "cancelled"
    GTT_STATUS_REJECTED = "rejected"
    GTT_STATUS_DELETED = "deleted"

# %%
class OrderState:
    OPEN = "OPEN"
    COMPLETE = "COMPLETE"
    REJECTED = "REJECTED"
    CANCELLED = "CANCELLED"

# %%
class Order:
    def __init__(self, variety, exchange, trading_symbol, transaction_type, quantity, product, order_type, price=None, trigger_price=None):
        self.variety=variety
        self.exchange=exchange
        self.trading_symbol=trading_symbol
        self.transaction_type=transaction_type
        self.quantity=quantity
        self.product=product
        self.order_type=order_type
        self.price=price
        self.trigger_price=trigger_price
        self.average_price=None # Average price at which the order is filled
        self.order_id=None
        self.order_status=None
        self.filled_qty = 0 # Filled quantity
        self.pending_qty = 0 # Pending qty
        self.order_place_timestamp = None # Timestamp when the order is placed
        self.order_timestamp = None # Broker timestamp
        self.exchange_timestamp = None #Exchange timestamp
        self.lastOrderUpdateTimestamp = None # Applicable if you modify the order Ex: Trailing SL
        self.message = None # In case any order rejection or any other error save the response from broker in this field
    
    def set_average_price(self, average_price):
        self.average_price = average_price
    
    def set_order_id(self, order_id):
        self.order_id = order_id
        
    def change_order_status(self, order_status):
        self.order_status = order_status

    def set_filled_qty(self, filled_qty):
        self.filled_qty = filled_qty

    def set_pending_qty(self, pending_qty):
        self.pending_qty = pending_qty

    def set_order_timestamp(self, order_timestamp):
        self.order_timestamp = order_timestamp

    def set_exchange_timestamp(self, exchange_timestamp):
        self.exchange_timestamp = exchange_timestamp

    def set_message(self, message):
        self.message = message

# %%
def placeOrder(order):
    broker = "Zerodha"
    kite = kite_handler
    try:
        order_id = kite.place_order(
        variety=kite.VARIETY_REGULAR,
        exchange=order.exchange,
        tradingsymbol=order.trading_symbol,
        transaction_type=order.transaction_type,
        quantity=order.quantity,
        price=order.price,
        trigger_price=order.trigger_price,
        product=order.product,
        order_type=order.order_type)
        logging.info(f'Order placed successfully, order_id = {order_id}')
        order.set_order_id(order_id)
    except Exception as e:
        logging.info("Order placement failed: {e}")
        raise Exception(str(e))

# %%
try_order = Order(variety=KiteConstants.VARIETY_REGULAR, exchange=KiteConstants.EXCHANGE_NSE, trading_symbol="ITC", transaction_type=KiteConstants.TRANSACTION_TYPE_BUY, quantity=1, product=KiteConstants.PRODUCT_MIS, order_type=KiteConstants.ORDER_TYPE_MARKET)

# %%
try_order_2 = Order(variety=KiteConstants.VARIETY_REGULAR, exchange=KiteConstants.EXCHANGE_NSE, trading_symbol="ITC", transaction_type=KiteConstants.TRANSACTION_TYPE_BUY, quantity=1, product=KiteConstants.PRODUCT_MIS, order_type=KiteConstants.ORDER_TYPE_MARKET)

# %%
placeOrder(try_order)
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/11" 200 None
# INFO:root:Order placed successfully, order_id = 241219201577784

# %%
placeOrder(try_order_2)
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/11" 200 None
# INFO:root:Order placed successfully, order_id = 241219201546167

# %%
try_order_2.order_id
# Out:
# '241219201546167'

# %%
data = {'account_id': 'BI3034', 'unfilled_quantity': 0, 'checksum': '', 'placed_by': 'BI3034', 'order_id': '241219201546167', 'exchange_order_id': '1100000042846003', 'parent_order_id': None, 'status': 'COMPLETE', 'status_message': None, 'status_message_raw': None, 'order_timestamp': '2024-12-19 13:37:24', 'exchange_update_timestamp': '2024-12-19 13:37:24', 'exchange_timestamp': '2024-12-19 13:37:24', 'variety': 'regular', 'exchange': 'NSE', 'tradingsymbol': 'ITC', 'instrument_token': 424961, 'order_type': 'MARKET', 'transaction_type': 'BUY', 'validity': 'DAY', 'product': 'MIS', 'quantity': 1, 'disclosed_quantity': 0, 'price': 0, 'trigger_price': 0, 'average_price': 467, 'filled_quantity': 1, 'pending_quantity': 0, 'cancelled_quantity': 0, 'market_protection': 0, 'meta': {}, 'tag': None, 'guid': '130032XxOepiy817I2E'}
pprint(data)
# Out:
# {'account_id': 'BI3034',
#  'average_price': 467,
#  'cancelled_quantity': 0,
#  'checksum': '',
#  'disclosed_quantity': 0,
#  'exchange': 'NSE',
#  'exchange_order_id': '1100000042846003',
#  'exchange_timestamp': '2024-12-19 13:37:24',
#  'exchange_update_timestamp': '2024-12-19 13:37:24',
#  'filled_quantity': 1,
#  'guid': '130032XxOepiy817I2E',
#  'instrument_token': 424961,
#  'market_protection': 0,
#  'meta': {},
#  'order_id': '241219201546167',
#  'order_timestamp': '2024-12-19 13:37:24',
#  'order_type': 'MARKET',
#  'parent_order_id': None,
#  'pending_quantity': 0,
#  'placed_by': 'BI3034',
#  'price': 0,
#  'product': 'MIS',
#  'quantity': 1,
#  'status': 'COMPLETE',
#  'status_message': None,
#  'status_message_raw': None,
#  'tag': None,
#  'tradingsymbol': 'ITC',
#  'transaction_type': 'BUY',
#  'trigger_price': 0,
#  'unfilled_quantity': 0,
#  'validity': 'DAY',
#  'variety': 'regular'}

# %%
def order_update(ws, data):
    logging.info(data)
    if(try_order.order_id == data['order_id']):
        try_order.set_exchange_timestamp(data['exchange_timestamp'])
        try_order.set_filled_qty(data['filled_quantity'])
        try_order.set_pending_qty(data['pending_quantity'])
        try_order.change_order_status(data['status'])

# %%
kws.on_order_update = order_update

# %%
try_order.order_status
# Out:
# 'COMPLETE'
